# %% [markdown]
# <br />
# <center>
#     <img src="picsforfriends/f8c9ef2d942631ef439e0409bd0dabd1.jpg" width=400 height=100 />
# </center>

# %% [markdown]
# # Importing all the required dependencies

# %%
import matplotlib
import numpy as np
import pandas as pd
import nltk
import re
from nltk.book import *
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import unicodedata
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from textblob import TextBlob, Word
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB         # Naive Bayes
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS 
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EmotionOptions

# %%
"""Using if and elif looping we are storing the dialogue in the characters name"""
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
with open("transcripts_friends/season_all/merged.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('Rachel:'):
            Rachel=Rachel+' '+(line[8:])
        elif line.startswith('Ross:'):
            Ross=Ross+' '+(line[6:])
        elif line.startswith('Monica:'):
            Monica=Monica+' '+(line[8:])
        elif line.startswith('Chandler:'):
            Chandler=Chandler+' '+(line[10:])
        if line.startswith('Phoebe:'):
            Phoebe=Phoebe+' '+(line[8:])
        if line.startswith('Joey:'):
            Joey=Joey+' '+(line[6:])

friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

# %%
import nltk
import ssl 
"""SSL is used for creating a secured seesion for authentication"""
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.tokenize import sent_tokenize 

    
stop_words = set(stopwords.words('english')) 

def clean_data(val):
    """This function returns clean data. This function will take data from open file pointers and drop new line and tab characters.
    Convert all the characters to lowercase to minimize the vocabulary and removes all the english stop words"""
    #remove new line and tab characters
    val = val.strip('\\n') 
    val = val.strip('\\t')
    # replacing new line and tab characters with white spaces 
    val = val.replace('\\n','')
    val = val.replace('\\t','')
    word_tokens = word_tokenize(str(val).lower().strip('[]') )
    #filtering sentences with stop words
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 

    filtered_sentence = [] 

    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 

    return list(filtered_sentence)

# %%
def plotwordcloud(word):
    """This function will spot word frequencies for every character"""
    stopwords = set(STOPWORDS) 
    words = clean_data(str(word).strip('[]'))
    unique_string=(" ").join(words)

    wordcloud = WordCloud(width = 800, height = 800, 
                    background_color ='white', 
                    stopwords = stopwords, 
                    min_font_size = 10).generate(unique_string) 
    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# %%
len(set(clean_data(str(friends_chars['RACHEL']).strip('[]')))) #unique word count
# Out:
# 6125

# %%
#Finding unique words used by all the characters
rachel_corpus=list(set(clean_data(str(friends_chars['RACHEL']).strip('[]'))))
ross_corpus=list(set(clean_data(str(friends_chars['ROSS']).strip('[]'))))
mon_corpus=list(set(clean_data(str(friends_chars['MONICA']).strip('[]'))))
joe_corpus=list(set(clean_data(str(friends_chars['JOEY']).strip('[]'))))
phoebs_corpus=list(set(clean_data(str(friends_chars['PHOEBE']).strip('[]'))))
chandler_corpus=list(set(clean_data(str(friends_chars['CHANDLER']).strip('[]'))))

# %%
#top 50 words used by Rachel
list(set(clean_data(str(friends_chars['RACHEL']).strip('[]'))))[:50]
# Out:
# ['playpen',
#  'tries',
#  'table',
#  'buries',
#  'research',
#  'bye-bye',
#  'lickers',
#  'espn',
#  'batch',
#  'spanish',
#  'forget',
#  'you�re',
#  't…leave',
#  'taught',
#  'faith',
#  'customer',
#  'horoscope',
#  'veil',
#  'rome',
#  'uhh',
#  'end',
#  'whispering',
#  'irritating',
#  'part',
#  'insane',
#  'nancy',
#  'crummy',
#  'virgin',
#  'hiding',
#  'nooo',
#  'sided',
#  'planetarium…',
#  'nooooooooo',
#  'dues',
#  'noone',
#  'boats',
#  'coloured',
#  'two-piece',
#  'one..we',
#  'spells',
#  "'till",
#  'really',
#  'woo',
#  'probably',
#  'quite',
#  'post',
#  'wallis',
#  'somewhat',
#  'clause',
#  'done']

# %%
from nltk import FreqDist
#Using inbuilt function, FreqDist we are trying to find out frequency of each word
dist_rach=FreqDist(rachel_corpus)
dist_mon=FreqDist(mon_corpus)
dist_joe=FreqDist(joe_corpus)
dist_ross=FreqDist(ross_corpus)
dist_phoebs=FreqDist(phoebs_corpus)
dist_chandler=FreqDist(chandler_corpus)

# %%
len(dist_joe)
# Out:
# 6239

# %%
#There are keys and values in each characters dictionary
vocab_rach=list(dist_rach.keys())
vocab_ross=list(dist_ross.keys())
vocab_mon=list(dist_mon.keys())
vocab_phoebs=list(dist_phoebs.keys())
vocab_joe=list(dist_joe.keys())
vocab_chandler=list(dist_chandler.keys())

# %%
vocab_rach[:10]
# Out:
# ['playpen',
#  'tries',
#  'table',
#  'buries',
#  'research',
#  'bye-bye',
#  'lickers',
#  'espn',
#  'batch',
#  'spanish']

# %%
words_rach=[w for w in rachel_corpus if len(w)>3]# and dist_rach[w]>1]
words_mon=[w for w in mon_corpus if len(w)>3] #and dist_mon[w]>50]
words_ross=[w for w in ross_corpus if len(w)>3] #and dist_ross[w]>50]
words_phoebs=[w for w in phoebs_corpus if len(w)>3] #and dist_phoebs[w]>50]
words_joe=[w for w in joe_corpus if len(w)>3]# and dist_joe[w]>50]
words_chandler=[w for w in chandler_corpus if len(w)>3]# and dist_chandler[w]>50]

# %%
words_rach
# Out:
# ['playpen',
#  'tries',
#  'table',
#  'buries',
#  'research',
#  'bye-bye',
#  'lickers',
#  'espn',
#  'batch',
#  'spanish',
#  'forget',
#  'you�re',
#  't…leave',
#  'taught',
#  'faith',
#  'customer',
#  'horoscope',
#  'veil',
#  'rome',
#  'whispering',
#  'irritating',
#  'part',
#  'insane',
#  'nancy',
#  'crummy',
#  'virgin',
#  'hiding',
#  'nooo',
#  'sided',
#  'planetarium…',
#  'nooooooooo',
#  'dues',
#  'noone',
#  'boats',
#  'coloured',
#  'two-piece',
#  'one..we',
#  'spells',
#  "'till",
#  'really',
#  'probably',
#  'quite',
#  'post',
#  'wallis',
#  'somewhat',
#  'clause',
#  'done',
#  'pause',
#  'cigs',
#  'minutes',
#  'blonde',
#  'nods',
#  'haze',
#  'wife',
#  'hey-hey-hey',
#  'response',
#  'gavin',
#  "c'mon",
#  'newspapers',
#  'pierced',
#  'eventually',
#  'characters',
#  'overheard',
#  'rich',
#  'things',
#  'peeping',
#  'halloween',
#  'small',
#  'on—joey',
#  'anticipation',
#  'joey—',
#  'umm…oh…who',
#  "'good",
#  'blow',
#  'knew',
#  'older',
#  'helmut',
#  'pony',
#  'flap',
#  'great-great',
#  'practising',
#  'times',
#  'cosmopolitan',
#  'related',
#  'brosnan',
#  'like…',
#  'kids…',
#  'maybe',
#  'induce',
#  'circley',
#  'haphazard',
#  'traumatic',
#  'mass',
#  'docks',
#  'stain',
#  'babies',
#  'mattered',
#  'girlfriend',
#  'undo',
#  'kicked',
#  'pouring',
#  'pile',
#  'funeral',
#  'boxer',
#  'becker',
#  'perspective',
#  'badminton',
#  'movements',
#  'pizza',
#  'disembarks',
#  'bing',
#  'sooo',
#  'appears',
#  'lamps',
#  'skates',
#  'uhhh…',
#  'thinking',
#  'pajmena',
#  'miss',
#  'is—i',
#  'hungry',
#  'guess',
#  'laughter',
#  'hardy',
#  'mrs.',
#  'scared',
#  'school',
#  'embarassed',
#  'josh-u-a',
#  'yeahh',
#  'magazine',
#  'uhh…',
#  'coordinator',
#  'weirdo',
#  'leads',
#  'rub-rub-rub',
#  'know—',
#  've-we',
#  'elizabeth',
#  'can—you',
#  'thank',
#  'offensive',
#  'continue',
#  'floor',
#  'flea',
#  "you're-you",
#  'lent',
#  'wall',
#  'wel-wel-well',
#  'belly',
#  'ohhhhhhhh',
#  'outside…',
#  'ahh…',
#  'orient',
#  'pooped',
#  'roommate',
#  'discomfort',
#  'look-look',
#  'twins',
#  'huh—wait',
#  'remote',
#  'fonzie',
#  'diversion',
#  'half-hour',
#  'lamauge',
#  'bunnies',
#  'we…we',
#  'waiting',
#  'twist',
#  '3000',
#  'junior',
#  'n-it',
#  'monday',
#  'advance',
#  'sorry',
#  'sisters',
#  'surprises',
#  'hats',
#  'exam',
#  'snowing',
#  'form',
#  'help',
#  'explain',
#  'misunderstanding',
#  'pitting',
#  'deals',
#  'joanne',
#  'him-',
#  'right',
#  'anastassakis/papasifakis',
#  'cramp',
#  'poster',
#  'aaron',
#  'pace',
#  'i—we',
#  'plan',
#  'handy',
#  'shirt',
#  'free',
#  'remembered',
#  'picks',
#  'puzzle',
#  'ughh',
#  'blue',
#  'biblical',
#  'spread',
#  'joins',
#  'item',
#  'move',
#  'montauk',
#  'kitten',
#  'my—why',
#  'special',
#  'naming',
#  'scene',
#  'pearls',
#  'fledermaus',
#  'cyborg',
#  'proposed',
#  'takin',
#  'look—no',
#  'cliff',
#  'bloomingdale',
#  'areas',
#  'yankees',
#  'madeleines',
#  'dealer',
#  'checkbook',
#  'vows',
#  'disagree',
#  'stay',
#  'alan',
#  'cabbage',
#  'yeti—i',
#  'greens',
#  'saran',
#  'cheeky',
#  'realises',
#  'glare',
#  'hm-m.',
#  'usher',
#  'show',
#  'stare',
#  'reps',
#  "'inspiration",
#  'wheeled',
#  'pancho',
#  'humoring',
#  'afterwards',
#  'draddle',
#  'know—oh',
#  'none',
#  'sock',
#  'grappa',
#  'forcing',
#  'bracelet',
#  'note',
#  'bored',
#  'curtain',
#  'sympathize',
#  'sneak',
#  'grabbing',
#  'macadamia',
#  'museum',
#  'cleaning',
#  'stella',
#  'standard',
#  'ross—really',
#  'drawing',
#  'buddy',
#  'resumes',
#  'instantly',
#  'offers',
#  'wrong',
#  'ohh—do',
#  '98.50',
#  'monster',
#  'star',
#  'foundation',
#  'right…there',
#  'work',
#  'what/',
#  'jokin',
#  'taxing',
#  'mazel',
#  'asleep',
#  'carol…lesbian',
#  'no-no-no…',
#  'spring',
#  'margaritas',
#  'helpful',
#  'earth',
#  'drivers',
#  'italian',
#  'geez',
#  'bags',
#  'just—wait',
#  'start',
#  'drove',
#  'aspirin',
#  'uterus',
#  'right.i',
#  'messing',
#  "i'll-i",
#  'pictionary',
#  "they'll-they",
#  'emily',
#  'hardware',
#  'cleared',
#  'water',
#  'chasing',
#  'plastic',
#  'kathy',
#  'glaring',
#  'mass-produced',
#  'slutty',
#  'else',
#  'spend',
#  'mormon',
#  'handing',
#  'joey…there',
#  'genitals',
#  'passionate',
#  'night..',
#  'seduce',
#  'smoke',
#  'hours',
#  'shin',
#  'adam',
#  'steal',
#  'earn',
#  'graveyard',
#  'momentary',
#  "'love",
#  'adjusting',
#  'took',
#  'court',
#  'chocolates',
#  'auditorium',
#  '10th',
#  'taurus',
#  'crowd',
#  't-shirt',
#  'dies',
#  'basic',
#  'non-ugly',
#  'also',
#  'tanned',
#  'paris',
#  'money',
#  'ladies',
#  'prisoner',
#  'causing',
#  'long',
#  'twice',
#  'dirty',
#  'exhibit',
#  'allowed',
#  'fours',
#  'sent',
#  'defines',
#  'michelle',
#  'crime',
#  'odds',
#  'hey-whoa-whoa-whoa',
#  'making',
#  'seamstress',
#  'glue',
#  'agree',
#  'you…are…not',
#  "'cause",
#  'checking',
#  'shhh',
#  'hope',
#  'checks',
#  'blinds',
#  'painful',
#  '—before',
#  'hmmmm',
#  'supervision',
#  'stewardess',
#  'parking',
#  'bigger',
#  'shoop',
#  'is—that',
#  'cheech',
#  "y'know",
#  'bedrooms',
#  'turn',
#  'ella',
#  'pom-poms',
#  'catch',
#  'nipples',
#  'sandy',
#  'at-at',
#  'week',
#  'simultaneously',
#  'drinks',
#  'just…it',
#  'club',
#  'coffee',
#  'sometimes',
#  'ohh-ohh-oh',
#  'comes',
#  'un-me',
#  'many',
#  'it…it',
#  'tillman',
#  'smart',
#  'bladder',
#  'fifty',
#  'counts',
#  'un-interested',
#  'yeah—but',
#  'loses',
#  'laugh',
#  'looking',
#  'wrinkled',
#  'staring',
#  'cotton',
#  'bunch',
#  'danny',
#  'tissues',
#  'incredibly',
#  'y-yeah',
#  'expert',
#  'aware',
#  'i-i—would',
#  'jars',
#  'throws',
#  "'cha",
#  'officially',
#  'progress',
#  'campbell',
#  'antenna',
#  'chases',
#  'distracted',
#  'danes',
#  'slippers',
#  'high',
#  'chain',
#  'tah-daaah',
#  'surprise…',
#  'wo-women',
#  'taken',
#  'fast',
#  'storing',
#  'bubbles',
#  'teeny-teeny',
#  'flicks',
#  's—we',
#  'opens',
#  'boxes',
#  'called',
#  'chase',
#  'just—we',
#  'actor',
#  'easy-pour',
#  'phoebe',
#  '.ok.',
#  'artelle',
#  'trips',
#  'puberty',
#  'crabtree',
#  'ohio',
#  'frame',
#  'struggling',
#  'lemonade',
#  'blushed',
#  'independence',
#  'screams',
#  'hook',
#  'brat',
#  'earrings',
#  'sudden',
#  'violated',
#  'ex-husband',
#  'information',
#  'damnit',
#  'migrate',
#  'anyway—umm',
#  'message',
#  'not-not',
#  'tire',
#  'respond',
#  'greasy',
#  'reflect',
#  'buys',
#  'merrill',
#  'bothered',
#  'obscene',
#  'except',
#  'ughhhh',
#  'eating',
#  'elbow',
#  'language',
#  'maitre',
#  'almost',
#  'radisson',
#  'sick-o',
#  'cream',
#  'turned',
#  'you…',
#  'you—but',
#  'want',
#  'geller-green',
#  'christian',
#  'crush—and',
#  'baby�s',
#  'latour',
#  'exited',
#  'hanger',
#  'rubs',
#  'delivery',
#  'chatracus',
#  'employee',
#  'messed',
#  'aside',
#  'squeeze',
#  'ohhhhhh',
#  'jeez',
#  'amateur',
#  'behind',
#  'mole',
#  'apologize',
#  'storming',
#  'kiss',
#  'marrying',
#  'hon-ey',
#  'dusting',
#  'sail',
#  'b-b-but',
#  'up—i',
#  'hallway',
#  '217.',
#  'schemp',
#  'character',
#  'luisa',
#  'master',
#  'process',
#  'page',
#  'appology',
#  'decaf',
#  'voice',
#  'valentine',
#  'king',
#  'joshua',
#  'ahhhhh',
#  'sigma',
#  'happ—i',
#  'silly',
#  'around',
#  'dead',
#  'lilies',
#  'antlers',
#  'oohh',
#  'dance',
#  'him…',
#  'promoted',
#  'point',
#  'metaphor',
#  'jeopardising',
#  'welch',
#  'confused',
#  'hesitates',
#  'numbers',
#  'undressing',
#  'breathe',
#  'screaming',
#  'lemon',
#  'morning',
#  'aaahhhh',
#  'shelley',
#  'innuendoes',
#  'follow',
#  'definitely',
#  'wooo',
#  'bleeding',
#  'lance',
#  'number',
#  'what—yeah—what',
#  'if-if',
#  'that—y',
#  'beginning',
#  'beeped',
#  'beautiful…',
#  'unbelievable',
#  'sorry-',
#  'bastards',
#  'celebrates',
#  'uncomfortable',
#  'shock',
#  'good—i',
#  'oooooooooh',
#  'stood',
#  's-let',
#  'jobs',
#  'teach',
#  'slut',
#  'pre-approved',
#  'cinamon',
#  'europe',
#  'sleeves',
#  'restaurant',
#  'fame',
#  'baked',
#  'hear—do',
#  'least',
#  'side',
#  'disregard',
#  'juicy',
#  'umm…now',
#  'denis',
#  'attracted',
#  'mork',
#  'gets',
#  'quickly',
#  'killing',
#  'whiff',
#  'hi-e',
#  'memories',
#  'pity-tone',
#  'cents',
#  'wishful',
#  'hopes',
#  'waking',
#  'initiated',
#  'fashion-impaired',
#  'yeah-yeah',
#  'squishy',
#  'healthy',
#  'nighttime',
#  'chute',
#  'missed',
#  'like..',
#  'spirit',
#  'sure',
#  'tuschy.',
#  'calvin',
#  'begin',
#  'got—why',
#  'winner',
#  'resume',
#  'flip',
#  'guy-in-van',
#  'sean',
#  'performance',
#  'uh…well',
#  'misjudged',
#  'too…',
#  'neighbor',
#  'ever',
#  'lunchbox',
#  'cross',
#  'kill',
#  'husband',
#  'returns',
#  'score',
#  'gesture',
#  'sixes',
#  'bitsy',
#  'drake',
#  'blouse',
#  'marry',
#  'english',
#  'ohhh',
#  'custard',
#  'crappy',
#  'silver',
#  'sagittarius',
#  'little…erotica',
#  'mcdowell',
#  'imitates',
#  'sailing',
#  'offence',
#  'craaaazy',
#  'grandma',
#  'sportswear',
#  'parachute',
#  'back…',
#  'hand',
#  'suitcase',
#  'mustard',
#  'waitresses',
#  'chucky',
#  'imitating',
#  'lags',
#  'bath',
#  'jumped',
#  'carefully',
#  'buying',
#  'seen',
#  'noodles',
#  'sucks',
#  'yearbook',
#  'frilly',
#  'digest',
#  'café',
#  'relationship',
#  'sconce',
#  'wood',
#  'starring',
#  'scratched',
#  'rivera',
#  'tips',
#  'meee',
#  'possible',
#  'barry..',
#  'landed',
#  'fire',
#  'understanding',
#  'neighborhood',
#  'pants',
#  'i-i—things',
#  'defends',
#  'capuchian',
#  'composure',
#  'knock',
#  'answers',
#  'm—here',
#  'jessica',
#  'crush',
#  'dorothy',
#  'ambercrombie',
#  '-teen',
#  'receptionist',
#  'uh-hmm',
#  'kidding—seriously',
#  'later',
#  'relived',
#  'hate',
#  'antsy',
#  'psyched',
#  'settings',
#  'sends',
#  'hangover',
#  'wh-what',
#  'navy',
#  'sighs',
#  'girlish',
#  'hat..',
#  'delicates',
#  'narrow',
#  'so..',
#  's—she',
#  'panicked',
#  'energy',
#  'pass',
#  'attention',
#  'brighter',
#  'matey',
#  'shoppin',
#  'time…she',
#  'frozen',
#  'know…kissed',
#  'realize',
#  'incredible',
#  'horribly',
#  'signing',
#  'read—yes',
#  'support',
#  'dreskin',
#  'soon',
#  'liebawitz',
#  'rrrooossss',
#  'faking',
#  'refers',
#  'loner',
#  'extravagant',
#  'musings',
#  'raises',
#  'sticking',
#  'matthew',
#  'breath',
#  'sleeve',
#  'bridal',
#  'excited',
#  'disbelief',
#  'caterers',
#  'they-they',
#  'stun',
#  'glamour',
#  'doooo',
#  'couch',
#  'ugh…',
#  'that…',
#  'storm',
#  'held',
#  "i'm-i",
#  'you…oh',
#  'pokes',
#  'floated',
#  'booze',
#  'rossy',
#  'chinese',
#  'robbing',
#  'packing',
#  'late',
#  'magic',
#  'bristles',
#  'the…that',
#  'yeah—ooh',
#  'mean—i',
#  'november',
#  'voluntarily',
#  'know',
#  'balloons',
#  'lasted',
#  'folder',
#  'trying',
#  'embarrassed',
#  'oh-oh-oh',
#  'just…made',
#  'correspondence',
#  'kick-',
#  'mine',
#  'phoebes',
#  'manages',
#  'answer',
#  'true',
#  'squat',
#  'marijuana',
#  'spot',
#  'however',
#  'remotely',
#  'awareness',
#  'territory',
#  'muffin',
#  'heads',
#  'think',
#  'pocket',
#  'said',
#  'anytime',
#  'baddest',
#  'colder',
#  'kennedy',
#  'spit-on-your-neck',
#  'meeting',
#  'hung',
#  'oh..go..oh..and',
#  "bitchin'",
#  'hire',
#  'steele',
#  'quick',
#  'effective',
#  'losers',
#  'grandmother',
#  'inviting',
#  'and…you',
#  'umbrella',
#  'trading',
#  'upon',
#  'cranking',
#  'what�s',
#  'phoe-be',
#  'vuitton',
#  'them…',
#  'wingman',
#  'issue',
#  'headrest',
#  'est�',
#  'seasons',
#  'briefcase',
#  'reluctantly',
#  'pfieffer',
#  'oh-ho',
#  'passes',
#  'london',
#  'clearly',
#  'ahhhh…',
#  'enriched',
#  'spots',
#  'wires',
#  'honks',
#  'bottom',
#  'interrupt',
#  'sting',
#  'clear',
#  'nato',
#  'uncle',
#  'cuter',
#  'pursuing',
#  'kudos',
#  'pact',
#  'fourth',
#  'chances',
#  'sight',
#  'frat',
#  'sobbing',
#  'lure',
#  'circles',
#  'revealing',
#  'carat',
#  'prefers',
#  'breathing',
#  'office-door',
#  'daughter',
#  'consummated',
#  'made',
#  'jewelry',
#  'lobster…',
#  'ears',
#  'relative',
#  'deltas',
#  'dejectedly',
#  'gynecologist',
#  'leathery',
#  'disgusted',
#  '26th',
#  'jill',
#  'perk',
#  'explained',
#  'slams',
#  "i'm-",
#  'compromise',
#  'farting',
#  'casserole',
#  'guys…',
#  'sputtery',
#  'gasp',
#  'clasp',
#  'central',
#  'mimics',
#  'publicity',
#  'chippy',
#  'triumph',
#  'rack',
#  'this…',
#  'porsching',
#  'jabba',
#  'sets',
#  'survived',
#  'married—i',
#  'climbs',
#  'waffles',
#  'actually—i-i',
#  'ohh-ha-ha',
#  's—since',
#  'gift',
#  'staying',
#  'written',
#  'snaps',
#  'officer',
#  'pouted',
#  'otherwise',
#  '20,000',
#  'walkin',
#  'sunset',
#  '—wow',
#  'place',
#  'case…',
#  'bang',
#  'pulled',
#  'kash',
#  'inappropriate',
#  'creeps',
#  'got—ohh',
#  'mounted',
#  'director',
#  'stutters',
#  'drunken',
#  'wiped',
#  'badly',
#  'rides',
#  'wiping',
#  'accomplish',
#  'meet',
#  'liotta',
#  'common',
#  'come—',
#  'save',
#  'console',
#  'reschedule',
#  'mitts',
#  'finkel',
#  'did-didn',
#  'are-what',
#  'unless',
#  'disapproves',
#  'pour',
#  'awww…',
#  'wh—hey',
#  'disrupt',
#  'hollow',
#  'comin',
#  'molly',
#  'jealous',
#  'stories',
#  'scrabble',
#  'backups',
#  'gazes',
#  'dave',
#  'desperate',
#  'john',
#  'mustache',
#  'event',
#  'even',
#  'photo',
#  'cider',
#  'ahhh…',
#  ...]

# %% [markdown]
# # Normalization and stemming

# %%
import nltk
porter=nltk.PorterStemmer()
"""Used stemming for reducing the words to root forms"""
[porter.stem(t) for t in vocab_rach]
[porter.stem(t) for t in vocab_ross]
[porter.stem(t) for t in vocab_mon]
[porter.stem(t) for t in vocab_phoebs]
[porter.stem(t) for t in vocab_joe]
[porter.stem(t) for t in vocab_chandler]
# Out:
# ['rules.',
#  'tri',
#  'tabl',
#  'mileu',
#  'thirty-year-old',
#  'bye-by',
#  'espn',
#  'forget',
#  '19.',
#  'cheat',
#  'you�r',
#  'shell',
#  'pay-per-view',
#  '..he',
#  'taught',
#  'bridg',
#  'custom',
#  'veil',
#  'uhh',
#  'spaceship',
#  'end',
#  'whisper',
#  'aaaaaa-dopt',
#  'pout',
#  'part',
#  '.stupid',
#  'insan',
#  'gag',
#  'batmobil',
#  'yemen',
#  'nanci',
#  'hide',
#  'bald',
#  'nooo',
#  'firm',
#  'unfulfil',
#  'valkyri',
#  'worker',
#  '90',
#  'was…th',
#  'not-i',
#  'vapor',
#  'ow-owww-owww',
#  'goal',
#  'exist',
#  'ba-',
#  'realli',
#  "'mistress",
#  'bread',
#  'woo',
#  'phaybobo',
#  'nate',
#  'probabl',
#  'quit',
#  'post',
#  'shaker',
#  'done',
#  'paus',
#  'minut',
#  'slyli',
#  'blond',
#  'nod',
#  'press',
#  'wife',
#  'hey-hey-hey',
#  'spoon',
#  'valuabl',
#  'respons',
#  "c'mon",
#  'arrang',
#  'newspap',
#  'eventu',
#  'charact',
#  'stress',
#  'boo-boo',
#  'killer',
#  'rich',
#  'thing',
#  'peep',
#  'buttock',
#  'small',
#  'snake',
#  'dip',
#  'ingredi',
#  'meet',
#  'blow',
#  'knew',
#  'older',
#  'studi',
#  'playstat',
#  'understand',
#  'racquet',
#  'suck',
#  'time',
#  'entitl',
#  'over-the-top',
#  'relat',
#  'lower',
#  'brosnan',
#  'sparrow',
#  'account',
#  'like…',
#  'mayb',
#  'degrad',
#  'tic',
#  'spinach',
#  'but-but',
#  'weekli',
#  'extend',
#  'stain',
#  'babi',
#  'matter',
#  'girlfriend',
#  'undo',
#  'kick',
#  'pour',
#  'down—let',
#  'just—whi',
#  'pile',
#  'funer',
#  'boxer',
#  'speedoes—that',
#  'becker',
#  'protest',
#  'perspect',
#  'pizza',
#  'bookbind',
#  'bing',
#  'jog',
#  'reunit',
#  'lamp',
#  'him..until',
#  'think',
#  'miss',
#  'match',
#  'grip',
#  'input',
#  'hungri',
#  'air',
#  'guess',
#  '.',
#  'laughter',
#  'mrs.',
#  'scare',
#  'school',
#  'embarass',
#  'muffin',
#  'conceiv',
#  'magazin',
#  'uhh…',
#  'plate',
#  'chameleon',
#  '99',
#  'epic',
#  'weirdo',
#  'ladl',
#  'elizabeth',
#  'thank',
#  '…come',
#  'incredul',
#  'continu',
#  'sad',
#  'floor',
#  "you're-y",
#  'chelsea',
#  'prescript',
#  'maria',
#  'whatsoev',
#  'wall',
#  'jamestown',
#  'belli',
#  'yelp',
#  'roommat',
#  'oil',
#  'once…did',
#  'du-du-i',
#  'twin',
#  'remot',
#  'fonzi',
#  'corn',
#  'half-hour',
#  'releas',
#  'north',
#  '16',
#  'bunni',
#  'addict',
#  'we…w',
#  'wait',
#  'twist',
#  'skirt',
#  'junior',
#  'palmol',
#  'monday',
#  'advanc',
#  'sorri',
#  'sister',
#  'ye-ye-yeah',
#  'surpris',
#  'videotap',
#  'hat',
#  'snow',
#  'form',
#  'wall-hang',
#  '3:30',
#  'climb',
#  'help',
#  'explain',
#  'pawn',
#  'blurri',
#  'misunderstand',
#  'deal',
#  'val',
#  'yuh-huh',
#  'right',
#  'strength',
#  'use',
#  'chick-flick',
#  'plan',
#  'shirt',
#  "'bout",
#  'free',
#  'kinki',
#  'rememb',
#  'scene',
#  'famili',
#  'pick',
#  'gym…treat',
#  'blue',
#  'circl',
#  'weirder',
#  'spread',
#  'item',
#  'join',
#  'move',
#  'tan',
#  'ball',
#  'special',
#  'name',
#  'scene',
#  'pearl',
#  'delveccio',
#  'propos',
#  'softwar',
#  'sake',
#  'cliff',
#  'bloomingdal',
#  'area',
#  'dealer',
#  'vow',
#  'embrac',
#  '46',
#  'reciept',
#  'disagre',
#  'stay',
#  'ran',
#  'alan',
#  'joey-ross',
#  'realis',
#  'glare',
#  'usher',
#  'show',
#  'stare',
#  'meadow',
#  'none',
#  'sock',
#  'map',
#  'falter',
#  'chandeli',
#  'promptli',
#  'rip',
#  'bracelet',
#  'note',
#  'bore',
#  'invent',
#  'knapsack',
#  'curtain',
#  'carton',
#  'oooo-ooh',
#  'convinc',
#  'recommend',
#  'grab',
#  'clean',
#  'standard',
#  'draw',
#  'dinah',
#  'buddi',
#  'resum',
#  'offer',
#  'wrong',
#  'kit-kat',
#  '98.50',
#  'star',
#  'foundat',
#  'touchi',
#  'work',
#  'way',
#  'print',
#  'then-then',
#  'bro',
#  'mazel',
#  'util',
#  'dealer',
#  'secretari',
#  '—mother',
#  'no—',
#  'score',
#  'see…',
#  'asleep',
#  'dictionary…',
#  'sheep',
#  'mon',
#  'spring',
#  'mourn',
#  'earth',
#  'complain',
#  'italian',
#  'nearest',
#  'geez',
#  'bag',
#  'appeal',
#  'math',
#  'price',
#  'start',
#  'drove',
#  'uteru',
#  'mess',
#  'pictionari',
#  'emili',
#  'clear',
#  'water',
#  'chase',
#  'plastic',
#  'kathi',
#  'glare',
#  '1,000',
#  'slutti',
#  'els',
#  'spend',
#  'upper',
#  'benefit',
#  'hand',
#  'hidden',
#  'passion',
#  'brows',
#  'smoke',
#  'hour',
#  'shin',
#  'steal',
#  'earn',
#  'aver',
#  'appli',
#  'hi',
#  'wee',
#  'pack',
#  'took',
#  'bosses�',
#  'relationship…',
#  'crowd',
#  'a-s-',
#  't-shirt',
#  'wink',
#  'goate',
#  'readi',
#  'die',
#  'stress',
#  'tamer',
#  'non-ugli',
#  'alik',
#  'also',
#  'wo',
#  'vendor',
#  'pari',
#  'money',
#  'mmmm',
#  'cous-cou',
#  'ladi',
#  'peeh',
#  '900',
#  'caus',
#  'long',
#  'twice',
#  'dirti',
#  'merg',
#  'allow',
#  'fear',
#  'congeni',
#  'needi',
#  'four',
#  'sent',
#  'vera',
#  'michel',
#  'only…',
#  'crime',
#  'odd',
#  'essenc',
#  '*all*',
#  'make',
#  'glue',
#  'agre',
#  'tiger',
#  'andrea',
#  "'thi",
#  'gener',
#  "'caus",
#  'check',
#  'shhh',
#  'hope',
#  'is-is-is-i',
#  'fore',
#  'check',
#  'sport',
#  'model',
#  'flower',
#  'pain',
#  'cancer',
#  'steami',
#  'bigger',
#  'testacl',
#  "y'know",
#  'bedroom',
#  'gay',
#  'turn',
#  'strategi',
#  'yarn',
#  'catch',
#  'nippl',
#  'type',
#  'week',
#  'simultan',
#  'manag',
#  'drink',
#  'club',
#  'coffe',
#  'sometim',
#  'come',
#  'burlesqu',
#  'd—',
#  'cooper',
#  'mani',
#  'transfer',
#  'boyish',
#  'cinemax',
#  'laud',
#  'smart',
#  'count',
#  'directli',
#  'lose',
#  'nick',
#  'minister…',
#  'kidnap',
#  'laugh',
#  'look',
#  'max',
#  'bogota',
#  'stare',
#  'half-eaten',
#  'newfound',
#  'cotton',
#  'chan',
#  'exaggeratedli',
#  'express',
#  'bunch',
#  'friggin',
#  'proceed',
#  'underwat',
#  'tissu',
#  'incred',
#  "'co-depend",
#  'awar',
#  'jar',
#  'throw',
#  'goralnik',
#  'offici',
#  'progress',
#  'pen',
#  'better..',
#  'high',
#  'hump',
#  '31.',
#  'jet',
#  'chain',
#  'taken',
#  'hoo-hoo',
#  'fast',
#  'wooden',
#  'unknow',
#  'open',
#  'box',
#  'call',
#  'boot',
#  'balanc',
#  'chase',
#  'actor',
#  'phoeb',
#  'f-hah',
#  'chemistri',
#  'sec',
#  'trip',
#  'trident',
#  'leer',
#  'thought…',
#  '007.',
#  'devot',
#  'ohio',
#  'frame',
#  'struggl',
#  'scream',
#  'hook',
#  'station',
#  'dialogu',
#  'sudden',
#  'violat',
#  'ear',
#  '—what',
#  'tetanu',
#  'inform',
#  'damnit',
#  'draft',
#  'tongue-ti',
#  'relax',
#  'messag',
#  'bill',
#  'hey',
#  'not-not',
#  'ditto',
#  'message.',
#  'janin',
#  'crawford',
#  'piti',
#  'intern',
#  'dillhol',
#  'buy',
#  'avert',
#  'except',
#  'linger',
#  'eat',
#  'ye',
#  'dull',
#  'maitr',
#  'golden',
#  'woo-hoo-hoo',
#  'almost',
#  'cream',
#  'turn',
#  'you…',
#  'brilliant',
#  'salt',
#  'gordon',
#  'want',
#  'mouth',
#  'servic',
#  'instruct',
#  'hanger',
#  'rub',
#  'stuffi',
#  'blaster',
#  'provid',
#  '—generos',
#  'insemin',
#  'ground',
#  "'ve",
#  'settl',
#  'mess',
#  'asid',
#  'squeez',
#  'sniff',
#  'crack',
#  'reminisc',
#  'mama',
#  'jeez',
#  'boobi',
#  'comic',
#  'ok.i',
#  '—one',
#  'mention',
#  'behind',
#  'san',
#  't—if',
#  'squint',
#  'untangl',
#  'victor',
#  'lo�look',
#  'apolog',
#  'disciplin',
#  'kiss',
#  'marri',
#  "d'know",
#  'glu',
#  'mime',
#  'honesti',
#  'hallway',
#  'schoolchildren',
#  'movement',
#  'charact',
#  'process',
#  'wanna..',
#  'page',
#  'chloe',
#  'indoor',
#  'traci',
#  'craftsmanship',
#  'voic',
#  'partner',
#  'valentin',
#  'king',
#  'joshua',
#  'fight',
#  '2',
#  "i'd..",
#  'ahhhhh',
#  'silli',
#  "y'think",
#  'al',
#  'bed',
#  'around',
#  'dead',
#  'lili',
#  'danc',
#  'think—oh',
#  'aah',
#  'donald',
#  'escort',
#  'point',
#  'not—no-no-no',
#  'confus',
#  'number',
#  'punch',
#  'breath',
#  'scream',
#  'lemon',
#  'morn',
#  'flew',
#  'shelley',
#  'see-saw',
#  'screen',
#  'capac',
#  'watch-',
#  'brandi',
#  'follow',
#  'definit',
#  'fricken.wait',
#  'guestroom',
#  'repel',
#  'duck',
#  'ya',
#  'number',
#  'no-o-o',
#  'if-if',
#  'begin',
#  'beep',
#  'chick',
#  'fluid—op',
#  'unbeliev',
#  'uncomfort',
#  'job',
#  'edit',
#  'teach',
#  'slut',
#  'prais',
#  'yea',
#  'cross',
#  'europ',
#  'sleev',
#  'restaur',
#  'isl',
#  'bake',
#  'death.wel',
#  'impend',
#  'least',
#  'lord',
#  'side',
#  'juici',
#  '15',
#  'attract',
#  'get',
#  'quickli',
#  'hear—',
#  'kill',
#  'explain',
#  'memori',
#  'inhospit',
#  'coke—',
#  'cent',
#  'hope',
#  'erupt',
#  'chew',
#  'cruel',
#  'abridg',
#  'appeal',
#  'wake',
#  'yeah-yeah',
#  'batman',
#  'bamboozl',
#  'financ',
#  'healthi',
#  'oh-ho-ho-ho',
#  'nighttim',
#  'board',
#  'whatcha',
#  "'shut",
#  'ass',
#  'miss',
#  'spirit',
#  'sure',
#  'self-suffici',
#  'network',
#  'projectil',
#  '3',
#  'creat',
#  'grant',
#  'winner',
#  'oh',
#  'flip',
#  'warmer',
#  'clicki',
#  'perform',
#  'handcuff',
#  'mug',
#  'liza',
#  'too…',
#  'mate',
#  'psychiatrist',
#  'freebi',
#  'carcass',
#  'ever',
#  'cross',
#  'pribe',
#  'kill',
#  'husband',
#  'clerk',
#  'death',
#  'return',
#  'score',
#  'spackel',
#  'leash',
#  'gestur',
#  'aerosol',
#  'tunnel',
#  'drake',
#  'blous',
#  'inventor',
#  're-pack',
#  'marri',
#  'heyyyy—what',
#  'ohhh',
#  'stinki',
#  'wha',
#  'crappi',
#  'silver',
#  'drive',
#  'rate',
#  'jumpi',
#  'imit',
#  'a…suppl',
#  'grandma',
#  'bitter',
#  'parachut',
#  'hand',
#  'mustard',
#  'flow',
#  'sex',
#  'beg',
#  'scent',
#  'la',
#  'hope',
#  'imit',
#  '29.',
#  'bath',
#  'jump',
#  'distast',
#  '1',
#  'care',
#  'buy',
#  'seen',
#  'noodl',
#  'suck',
#  'racist',
#  'spinster',
#  'antihistamin',
#  'sweetum',
#  'surrogaci',
#  'copier',
#  'relationship',
#  'mesquit',
#  'wood',
#  'star',
#  'possibl',
#  'metaphor',
#  'fire',
#  'perk',
#  'understand',
#  'pant',
#  'mourn',
#  'posterior',
#  'knock',
#  'weddingi',
#  'shrink',
#  'answer',
#  'ill',
#  'jessica',
#  'crush',
#  'dorothi',
#  'cheeckbon',
#  'wow',
#  'polici',
#  'night…',
#  'receptionist',
#  'maybe-maybe-mayb',
#  'later',
#  'digniti',
#  'wrinkl',
#  'sway',
#  'tobi',
#  'hate',
#  'moment',
#  'planeload',
#  'oldest',
#  'www.hahanotsomuch.com',
#  'cubicl',
#  'uso',
#  'psych',
#  'memo',
#  'send',
#  'wh-what',
#  'sigh',
#  'memori',
#  'jelli',
#  'relinquish',
#  'narrow',
#  'warrior',
#  'so..',
#  "'whole",
#  'sugarless',
#  'sor',
#  'panick',
#  'energi',
#  'pass',
#  'softball..',
#  'attent',
#  'briefcase…',
#  'brighter',
#  'frozen',
#  'jerri',
#  'realiz',
#  'incred',
#  'sign',
#  'support',
#  'soon',
#  'll…i',
#  'uh…',
#  'diana',
#  'fake',
#  'prototyp',
#  '..she',
#  'rais',
#  'stick',
#  'matthew',
#  'breath',
#  'sleev',
#  'melba',
#  'wee-we',
#  'lick',
#  'bridal',
#  '1979',
#  'dana',
#  'expertis',
#  'excit',
#  '�kay',
#  'commut',
#  'libe',
#  '48',
#  'consciou',
#  'snooti',
#  'couch',
#  'hornswoggl',
#  'watch',
#  'storm',
#  'penni',
#  'held',
#  'subconsci',
#  'one-year-old',
#  'limps-a-lot',
#  'tast',
#  'primit',
#  'chines',
#  'valdez',
#  'intimid',
#  'pack',
#  'shut',
#  'overdu',
#  'late',
#  'magic',
#  'deject',
#  'voluntarili',
#  'buffet',
#  'know',
#  'motiv',
#  'last',
#  'tri',
#  'embarrass',
#  'oh-oh-oh',
#  'salad',
#  'detroit',
#  'chequ',
#  'box',
#  'espresso',
#  'ready…',
#  'mine',
#  'answer',
#  'true',
#  'y-y-yeeesss',
#  'hours…',
#  'articl',
#  'examin',
#  'howev',
#  'spot',
#  'measur',
#  'hate',
#  'dresser',
#  'triplet',
#  'head',
#  'think',
#  'frisbe',
#  'hottest',
#  'unconsci',
#  'pocket',
#  'loosen',
#  'said',
#  'anytim',
#  'alphabet',
#  'baddest',
#  'a-huh',
#  'youngest',
#  'care',
#  'bankrupt',
#  'kennedi',
#  'nude',
#  'meet',
#  'hung',
#  'bother',
#  'night-night',
#  'hire',
#  'quick',
#  'juri',
#  'let',
#  'loser',
#  'grandmoth',
#  'dee',
#  'tineal',
#  'mow',
#  'wango',
#  'trade',
#  'rhythm',
#  'gladd',
#  'defenc',
#  'statist',
#  'wellll',
#  'code',
#  'what�',
#  'wet',
#  'issu',
#  'lime',
#  'serial',
#  'briefcas',
#  'tag',
#  'involv',
#  'oh-ho',
#  'pass',
#  'tedlock',
#  'london',
#  'clearli',
#  'till',
#  'spot',
#  'honk',
#  'bummer',
#  'freshen',
#  'scar',
#  'bottom',
#  '1a',
#  'girth',
#  'interrupt',
#  'fling',
#  'sting',
#  'duti',
#  'clear',
#  'uncl',
#  'pursu',
#  'phobo',
#  'commit',
#  'playth',
#  'slide',
#  'messer',
#  'leetch',
#  'pact',
#  'fourth',
#  '—mi',
#  'chanc',
#  'sight',
#  'reveal',
#  'circl',
#  ...]

# %% [markdown]
# # Lemmatization stemming, but all stems are valid words

# %%
WNLemma=nltk.WordNetLemmatizer()
"""return the base or dictionary form of a word"""
stem_freq_words_rach=[WNLemma.lemmatize(t) for t in words_rach]
stem_freq_words_ross=[WNLemma.lemmatize(t) for t in words_ross]
stem_freq_words_chandler=[WNLemma.lemmatize(t) for t in words_chandler]
stem_freq_words_mon=[WNLemma.lemmatize(t) for t in words_mon]
stem_freq_words_phoebs=[WNLemma.lemmatize(t) for t in words_phoebs]
stem_freq_words_joe=[WNLemma.lemmatize(t) for t in words_joe]

# %%
stem_freq_words_chandler
# Out:
# ['rules.',
#  'try',
#  'table',
#  'mileu',
#  'thirty-year-old',
#  'bye-bye',
#  'espn',
#  'forget',
#  'cheat',
#  'you�re',
#  'shell',
#  'pay-per-view',
#  '..he',
#  'taught',
#  'bridge',
#  'customer',
#  'veil',
#  'spaceship',
#  'whispering',
#  'aaaaaa-doption',
#  'pouting',
#  'part',
#  '.stupid',
#  'insane',
#  'gagging',
#  'batmobile',
#  'yemen',
#  'nancy',
#  'hiding',
#  'baldness',
#  'nooo',
#  'firm',
#  'unfulfilling',
#  'valkyrie',
#  'worker',
#  'was…the',
#  'not-i',
#  'vaporizing',
#  'ow-owww-owww',
#  'goal',
#  'exist',
#  'really',
#  "'mistress",
#  'bread',
#  'phaybobo',
#  'nate',
#  'probably',
#  'quite',
#  'post',
#  'shaker',
#  'done',
#  'pause',
#  'minute',
#  'slyly',
#  'blonde',
#  'nod',
#  'pressed',
#  'wife',
#  'hey-hey-hey',
#  'spoon',
#  'valuable',
#  'response',
#  "c'mon",
#  'arrangement',
#  'newspaper',
#  'eventually',
#  'character',
#  'stressed',
#  'boo-boo',
#  'killer',
#  'rich',
#  'thing',
#  'peeping',
#  'buttock',
#  'small',
#  'snaking',
#  'ingredient',
#  'meet',
#  'blow',
#  'knew',
#  'older',
#  'study',
#  'playstation',
#  'understandable',
#  'racquet',
#  'sucked',
#  'time',
#  'entitled',
#  'over-the-top',
#  'related',
#  'lower',
#  'brosnan',
#  'sparrow',
#  'account',
#  'like…',
#  'maybe',
#  'degrades',
#  'spinach',
#  'but-but',
#  'weekly',
#  'extends',
#  'stain',
#  'baby',
#  'mattered',
#  'girlfriend',
#  'undo',
#  'kicked',
#  'pouring',
#  'down—let',
#  'just—why',
#  'pile',
#  'funeral',
#  'boxer',
#  'speedoes—that',
#  'becker',
#  'protested',
#  'perspective',
#  'pizza',
#  'bookbinder',
#  'bing',
#  'jogging',
#  'reunited',
#  'lamp',
#  'him..until',
#  'thinking',
#  'miss',
#  'match',
#  'grip',
#  'input',
#  'hungry',
#  'guess',
#  'laughter',
#  'mrs.',
#  'scared',
#  'school',
#  'embarassed',
#  'muffin',
#  'conceived',
#  'magazine',
#  'uhh…',
#  'plate',
#  'chameleon',
#  'epic',
#  'weirdo',
#  'ladle',
#  'elizabeth',
#  'thank',
#  '…come',
#  'incredulous',
#  'continue',
#  'floor',
#  "you're-you",
#  'chelsea',
#  'prescription',
#  'maria',
#  'whatsoever',
#  'wall',
#  'jamestown',
#  'belly',
#  'yelp',
#  'roommate',
#  'oil',
#  'once…did',
#  'du-du-i',
#  'twin',
#  'remote',
#  'fonzie',
#  'corn',
#  'half-hour',
#  'release',
#  'north',
#  'bunny',
#  'addict',
#  'we…we',
#  'waiting',
#  'twist',
#  'skirt',
#  'junior',
#  'palmolive',
#  'monday',
#  'advance',
#  'sorry',
#  'sister',
#  'ye-ye-yeah',
#  'surprise',
#  'videotape',
#  'hat',
#  'snowing',
#  'form',
#  'wall-hanging',
#  '3:30',
#  'climbed',
#  'help',
#  'explain',
#  'pawn',
#  'blurry',
#  'misunderstanding',
#  'deal',
#  'yuh-huh',
#  'right',
#  'strength',
#  'chick-flick',
#  'plan',
#  'shirt',
#  "'bout",
#  'free',
#  'kinky',
#  'remembered',
#  'scene',
#  'family',
#  'pick',
#  'gym…treat',
#  'blue',
#  'circled',
#  'weirder',
#  'spread',
#  'item',
#  'join',
#  'move',
#  'tanning',
#  'balled',
#  'special',
#  'naming',
#  'scene',
#  'pearl',
#  'delveccio',
#  'proposed',
#  'software',
#  'sake',
#  'cliff',
#  'bloomingdale',
#  'area',
#  'dealer',
#  'vow',
#  'embrace',
#  'reciept',
#  'disagree',
#  'stay',
#  'alan',
#  'joey-ross',
#  'realises',
#  'glare',
#  'usher',
#  'show',
#  'stare',
#  'meadow',
#  'none',
#  'sock',
#  'map',
#  'falter',
#  'chandelier',
#  'promptly',
#  'bracelet',
#  'note',
#  'bored',
#  'inventing',
#  'knapsack',
#  'curtain',
#  'carton',
#  'oooo-ooh',
#  'convinced',
#  'recommending',
#  'grabbing',
#  'cleaning',
#  'standard',
#  'drawing',
#  'dinah',
#  'buddy',
#  'resume',
#  'offer',
#  'wrong',
#  'kit-kats',
#  '98.50',
#  'star',
#  'foundation',
#  'touchy',
#  'work',
#  'printed',
#  'then-then',
#  'mazel',
#  'utility',
#  'dealer',
#  'secretary',
#  '—mother',
#  'scored',
#  'see…',
#  'asleep',
#  'dictionary…',
#  'sheep',
#  'spring',
#  'mourning',
#  'earth',
#  'complain',
#  'italian',
#  'nearest',
#  'geez',
#  'bag',
#  'appeal',
#  'math',
#  'pricing',
#  'start',
#  'drove',
#  'uterus',
#  'messing',
#  'pictionary',
#  'emily',
#  'cleared',
#  'water',
#  'chasing',
#  'plastic',
#  'kathy',
#  'glaring',
#  '1,000',
#  'slutty',
#  'else',
#  'spend',
#  'upper',
#  'benefit',
#  'handing',
#  'hidden',
#  'passionate',
#  'browsing',
#  'smoke',
#  'hour',
#  'shin',
#  'steal',
#  'earn',
#  'aver',
#  'applying',
#  'pack',
#  'took',
#  'bosses�',
#  'relationship…',
#  'crowd',
#  'a-s-s',
#  't-shirt',
#  'wink',
#  'goatee',
#  'ready',
#  'dy',
#  'stress',
#  'tamer',
#  'non-ugly',
#  'alike',
#  'also',
#  'vendor',
#  'paris',
#  'money',
#  'mmmm',
#  'cous-cous',
#  'lady',
#  'peehe',
#  'causing',
#  'long',
#  'twice',
#  'dirty',
#  'merge',
#  'allowed',
#  'feared',
#  'congeniality',
#  'needy',
#  'four',
#  'sent',
#  'vera',
#  'michelle',
#  'only…',
#  'crime',
#  'odds',
#  'essence',
#  '*all*',
#  'making',
#  'glue',
#  'agree',
#  'tiger',
#  'andrea',
#  "'this",
#  'generous',
#  "'cause",
#  'checking',
#  'shhh',
#  'hope',
#  'is-is-is-is',
#  'fore',
#  'check',
#  'sport',
#  'model',
#  'flower',
#  'painful',
#  'cancer',
#  'steamy',
#  'bigger',
#  'testacles',
#  "y'know",
#  'bedroom',
#  'turn',
#  'strategy',
#  'yarn',
#  'catch',
#  'nipple',
#  'typing',
#  'week',
#  'simultaneously',
#  'manage',
#  'drink',
#  'club',
#  'coffee',
#  'sometimes',
#  'come',
#  'burlesque',
#  'cooperative',
#  'many',
#  'transferring',
#  'boyish',
#  'cinemax',
#  'laude',
#  'smart',
#  'count',
#  'directly',
#  'loses',
#  'nick',
#  'minister…',
#  'kidnap',
#  'laugh',
#  'looking',
#  'bogota',
#  'staring',
#  'half-eaten',
#  'newfound',
#  'cotton',
#  'chan',
#  'exaggeratedly',
#  'expression',
#  'bunch',
#  'friggin',
#  'proceeding',
#  'underwater',
#  'tissue',
#  'incredibly',
#  "'co-dependent",
#  'aware',
#  'jar',
#  'throw',
#  'goralnik',
#  'officially',
#  'progress',
#  'pen',
#  'better..',
#  'high',
#  'humping',
#  'chain',
#  'taken',
#  'hoo-hoos',
#  'fast',
#  'wooden',
#  'unknowable',
#  'open',
#  'box',
#  'called',
#  'boot',
#  'balance',
#  'chase',
#  'actor',
#  'phoebe',
#  'f-hah',
#  'chemistry',
#  'trip',
#  'trident',
#  'leering',
#  'thought…',
#  '007.',
#  'devoted',
#  'ohio',
#  'frame',
#  'struggling',
#  'scream',
#  'hook',
#  'station',
#  'dialogue',
#  'sudden',
#  'violated',
#  'earring',
#  '—what',
#  'tetanus',
#  'information',
#  'damnit',
#  'draft',
#  'tongue-tied',
#  'relaxing',
#  'message',
#  'bill',
#  'not-not',
#  'ditto',
#  'message.',
#  'janine',
#  'crawford',
#  'pity',
#  'international',
#  'dillhole',
#  'buy',
#  'averts',
#  'except',
#  'lingers',
#  'eating',
#  'dull',
#  'maitre',
#  'golden',
#  'woo-hoo-hoo',
#  'almost',
#  'cream',
#  'turned',
#  'you…',
#  'brilliant',
#  'salt',
#  'gordon',
#  'want',
#  'mouthful',
#  'service',
#  'instruction',
#  'hanger',
#  'rub',
#  'stuffy',
#  'blaster',
#  'provide',
#  '—generosity',
#  'insemination',
#  'ground',
#  'settled',
#  'messed',
#  'aside',
#  'squeeze',
#  'sniff',
#  'cracked',
#  'reminiscing',
#  'mama',
#  'jeez',
#  'booby',
#  'comic',
#  'ok.i',
#  '—one',
#  'mentioning',
#  'behind',
#  't—if',
#  'squint',
#  'untangled',
#  'victor',
#  'lo�look',
#  'apologize',
#  'disciplining',
#  'kiss',
#  'marrying',
#  "d'know",
#  'glued',
#  'mime',
#  'honesty',
#  'hallway',
#  'schoolchildren',
#  'movement',
#  'character',
#  'process',
#  'wanna..',
#  'page',
#  'chloe',
#  'indoor',
#  'tracy',
#  'craftsmanship',
#  'voice',
#  'partner',
#  'valentine',
#  'king',
#  'joshua',
#  'fighting',
#  "i'd..",
#  'ahhhhh',
#  'silly',
#  "y'think",
#  'around',
#  'dead',
#  'lily',
#  'dance',
#  'think—oh',
#  'donald',
#  'escorting',
#  'point',
#  'not—no-no-no',
#  'confused',
#  'number',
#  'punching',
#  'breathe',
#  'screaming',
#  'lemon',
#  'morning',
#  'flew',
#  'shelley',
#  'see-saw',
#  'screening',
#  'capacity',
#  'watch-',
#  'brandy',
#  'follow',
#  'definitely',
#  'fricken.waiter',
#  'guestroom',
#  'repeller',
#  'duck',
#  'number',
#  'no-o-o',
#  'if-if',
#  'beginning',
#  'beeped',
#  'chick',
#  'fluid—op',
#  'unbelievable',
#  'uncomfortable',
#  'job',
#  'edition',
#  'teach',
#  'slut',
#  'praise',
#  'crossing',
#  'europe',
#  'sleeve',
#  'restaurant',
#  'isle',
#  'baked',
#  'death.well',
#  'impending',
#  'least',
#  'lord',
#  'side',
#  'juicy',
#  'attracted',
#  'get',
#  'quickly',
#  'hear—',
#  'killing',
#  'explaining',
#  'memory',
#  'inhospitable',
#  'coke—',
#  'cent',
#  'hope',
#  'erupts',
#  'chewing',
#  'cruel',
#  'abridgment',
#  'appealing',
#  'waking',
#  'yeah-yeah',
#  'batman',
#  'bamboozled',
#  'financing',
#  'healthy',
#  'oh-ho-ho-ho',
#  'nighttime',
#  'boarding',
#  'whatcha',
#  "'shut",
#  'missed',
#  'spirit',
#  'sure',
#  'self-sufficient',
#  'network',
#  'projectile',
#  'create',
#  'granted',
#  'winner',
#  'flip',
#  'warmer',
#  'clicky',
#  'performance',
#  'handcuff',
#  'liza',
#  'too…',
#  'mate',
#  'psychiatrist',
#  'freebie',
#  'carcass',
#  'ever',
#  'cross',
#  'pribe',
#  'kill',
#  'husband',
#  'clerk',
#  'death',
#  'return',
#  'score',
#  'spackel',
#  'leash',
#  'gesture',
#  'aerosol',
#  'tunnel',
#  'drake',
#  'blouse',
#  'inventor',
#  're-pack',
#  'marry',
#  'heyyyy—what',
#  'ohhh',
#  'stinky',
#  'crappy',
#  'silver',
#  'drive',
#  'rate',
#  'jumpy',
#  'imitates',
#  'a…supple',
#  'grandma',
#  'bitter',
#  'parachute',
#  'hand',
#  'mustard',
#  'flow',
#  'scent',
#  'hoped',
#  'imitating',
#  'bath',
#  'jumped',
#  'distasteful',
#  'carefully',
#  'buying',
#  'seen',
#  'noodle',
#  'suck',
#  'racist',
#  'spinster',
#  'antihistamine',
#  'sweetums',
#  'surrogacy',
#  'copier',
#  'relationship',
#  'mesquite',
#  'wood',
#  'starring',
#  'possible',
#  'metaphorically',
#  'fire',
#  'perked',
#  'understanding',
#  'pant',
#  'mournful',
#  'posterior',
#  'knock',
#  'weddingy',
#  'shrink',
#  'answer',
#  'jessica',
#  'crush',
#  'dorothy',
#  'cheeckbones',
#  'policy',
#  'night…',
#  'receptionist',
#  'maybe-maybe-maybe',
#  'later',
#  'dignity',
#  'wrinkle',
#  'sway',
#  'toby',
#  'hate',
#  'moment',
#  'planeload',
#  'oldest',
#  'www.hahanotsomuch.com',
#  'cubicle',
#  'psyched',
#  'memo',
#  'sends',
#  'wh-what',
#  'sigh',
#  'memorial',
#  'jelly',
#  'relinquish',
#  'narrow',
#  'warrior',
#  'so..',
#  "'whole",
#  'sugarless',
#  'panicked',
#  'energy',
#  'pas',
#  'softball..',
#  'attention',
#  'briefcase…',
#  'brighter',
#  'frozen',
#  'jerry',
#  'realize',
#  'incredible',
#  'signing',
#  'support',
#  'soon',
#  'll…i',
#  'diana',
#  'faking',
#  'prototype',
#  '..she',
#  'raise',
#  'sticking',
#  'matthew',
#  'breath',
#  'sleeve',
#  'melba',
#  'wee-wees',
#  'licked',
#  'bridal',
#  '1979',
#  'dana',
#  'expertise',
#  'excited',
#  '�kay',
#  'commute',
#  'libe',
#  'conscious',
#  'snooty',
#  'couch',
#  'hornswoggle',
#  'watch',
#  'storm',
#  'penny',
#  'held',
#  'subconscious',
#  'one-year-old',
#  'limps-a-lot',
#  'taste',
#  'primitive',
#  'chinese',
#  'valdez',
#  'intimidated',
#  'packing',
#  'shuts',
#  'overdue',
#  'late',
#  'magic',
#  'dejected',
#  'voluntarily',
#  'buffet',
#  'know',
#  'motivational',
#  'lasted',
#  'trying',
#  'embarrassed',
#  'oh-oh-oh',
#  'salad',
#  'detroit',
#  'cheque',
#  'espresso',
#  'ready…',
#  'mine',
#  'answer',
#  'true',
#  'y-y-yeeesss',
#  'hours…',
#  'article',
#  'examining',
#  'however',
#  'spot',
#  'measuring',
#  'hated',
#  'dresser',
#  'triplet',
#  'head',
#  'think',
#  'frisbee',
#  'hottest',
#  'unconscious',
#  'pocket',
#  'loosen',
#  'said',
#  'anytime',
#  'alphabetically',
#  'baddest',
#  'a-huh',
#  'youngest',
#  'caring',
#  'bankrupt',
#  'kennedy',
#  'nude',
#  'meeting',
#  'hung',
#  'bothering',
#  'night-night',
#  'hire',
#  'quick',
#  'jury',
#  'loser',
#  'grandmother',
#  'tineals',
#  'mowing',
#  'wango',
#  'trading',
#  'rhythm',
#  'gladd',
#  'defence',
#  'statistical',
#  'wellll',
#  'code',
#  'what�s',
#  'issue',
#  'lime',
#  'serial',
#  'briefcase',
#  'involves',
#  'oh-ho',
#  'pass',
#  'tedlock',
#  'london',
#  'clearly',
#  'till',
#  'spot',
#  'honk',
#  'bummer',
#  'freshener',
#  'scar',
#  'bottom',
#  'girth',
#  'interrupt',
#  'fling',
#  'sting',
#  'duty',
#  'clear',
#  'uncle',
#  'pursuing',
#  'phobo',
#  'commitment',
#  'plaything',
#  'slide',
#  'messers',
#  'leetch',
#  'pact',
#  'fourth',
#  'chance',
#  'sight',
#  'revealing',
#  'circle',
#  'breathing',
#  'daughter',
#  'lima',
#  'spotting',
#  'made',
#  'jewelry',
#  'ear',
#  'entertainment',
#  'visitor',
#  'authorization',
#  'period',
#  'disgusted',
#  'jill',
#  'perk',
#  'slam',
#  'compromise',
#  'women…',
#  'guys…',
#  'gasp',
#  'smack',
#  'central',
#  'costume…',
#  'mimic',
#  'triumph',
#  'rack',
#  'this…',
#  'need—',
#  'simian',
#  'set',
#  'regular',
#  'survived',
#  'factor',
#  'land',
#  'upset—for',
#  'waffle',
#  'humour',
#  'gift',
#  'staying',
#  'written',
#  'illegal',
#  'officer',
#  'checkin',
#  'otherwise',
#  'chick-chick',
#  'damone',
#  'petite',
#  'turtle',
#  'ordinary',
#  'electromagnetic',
#  'place',
#  'taunt',
#  'pulled',
#  'inappropriate',
#  'creep',
#  'algernon',
#  'director',
#  'resist',
#  'drunken',
#  'badly',
#  'fortunately',
#  'regularly',
#  'wiping',
#  'swimsuit',
#  'meet',
#  'common',
#  'save',
#  ...]

# %%
"""Tagging the list of noun,pronoun,verbs,etc"""
nltk.pos_tag(vocab_rach)
# Out:
# [('playpen', 'JJ'),
#  ('tries', 'NNS'),
#  ('table', 'JJ'),
#  ('buries', 'NNS'),
#  ('research', 'NN'),
#  ('bye-bye', 'JJ'),
#  ('lickers', 'NNS'),
#  ('espn', 'VBP'),
#  ('batch', 'NN'),
#  ('spanish', 'JJ'),
#  ('forget', 'NN'),
#  ('you�re', 'NNS'),
#  ('t…leave', 'VBP'),
#  ('taught', 'VBN'),
#  ('faith', 'JJ'),
#  ('customer', 'NN'),
#  ('horoscope', 'NN'),
#  ('veil', 'FW'),
#  ('rome', 'NN'),
#  ('uhh', 'JJ'),
#  ('end', 'NN'),
#  ('whispering', 'VBG'),
#  ('irritating', 'VBG'),
#  ('part', 'NN'),
#  ('insane', 'NN'),
#  ('nancy', 'NN'),
#  ('crummy', 'NN'),
#  ('virgin', 'NN'),
#  ('hiding', 'VBG'),
#  ('nooo', 'RB'),
#  ('sided', 'VBN'),
#  ('planetarium…', 'NN'),
#  ('nooooooooo', 'NN'),
#  ('dues', 'VBZ'),
#  ('noone', 'CD'),
#  ('boats', 'NNS'),
#  ('coloured', 'VBD'),
#  ('two-piece', 'JJ'),
#  ('one..we', 'NN'),
#  ('spells', 'NNS'),
#  ("'till", 'POS'),
#  ('really', 'RB'),
#  ('woo', 'VBZ'),
#  ('probably', 'RB'),
#  ('quite', 'RB'),
#  ('post', 'JJ'),
#  ('wallis', 'NN'),
#  ('somewhat', 'RB'),
#  ('clause', 'VBZ'),
#  ('done', 'VBN'),
#  ('pause', 'NN'),
#  ('cigs', 'NN'),
#  ('minutes', 'NNS'),
#  ('blonde', 'VBP'),
#  ('nods', 'NNS'),
#  ('haze', 'JJ'),
#  ('wife', 'NN'),
#  ('hey-hey-hey', 'JJ'),
#  ('response', 'NN'),
#  ('gavin', 'NN'),
#  ("c'mon", 'NN'),
#  ('newspapers', 'NNS'),
#  ('pierced', 'VBD'),
#  ('eventually', 'RB'),
#  ('characters', 'NNS'),
#  ('overheard', 'VBP'),
#  ('rich', 'JJ'),
#  ('things', 'NNS'),
#  ('peeping', 'VBG'),
#  ('halloween', 'JJ'),
#  ('small', 'JJ'),
#  ('on—joey', 'JJ'),
#  ('anticipation', 'NN'),
#  ('joey—', 'NN'),
#  ('umm…oh…who', 'JJ'),
#  ("'good", 'VBD'),
#  ('blow', 'JJ'),
#  ('knew', 'VBD'),
#  ('older', 'JJR'),
#  ('helmut', 'NN'),
#  ('pony', 'NN'),
#  ('flap', 'VBD'),
#  ('great-great', 'NN'),
#  ('practising', 'NN'),
#  ('times', 'NNS'),
#  ('cosmopolitan', 'VBP'),
#  ('related', 'JJ'),
#  ('brosnan', 'NN'),
#  ('like…', 'NN'),
#  ('kids…', 'NN'),
#  ('maybe', 'RB'),
#  ('induce', 'VB'),
#  ('circley', 'NN'),
#  ('haphazard', 'NN'),
#  ('ood', 'VBD'),
#  ('traumatic', 'JJ'),
#  ('mass', 'NN'),
#  ('docks', 'NNS'),
#  ('stain', 'VBP'),
#  ('babies', 'NNS'),
#  ('mattered', 'VBD'),
#  ('girlfriend', 'JJ'),
#  ('undo', 'JJ'),
#  ('kicked', 'VBD'),
#  ('pouring', 'VBG'),
#  ('pile', 'JJ'),
#  ('funeral', 'JJ'),
#  ('boxer', 'NN'),
#  ('becker', 'NN'),
#  ('perspective', 'JJ'),
#  ('badminton', 'NN'),
#  ('movements', 'NNS'),
#  ('pizza', 'VBP'),
#  ('disembarks', 'NNS'),
#  ('bing', 'VBG'),
#  ('sooo', 'NN'),
#  ('appears', 'VBZ'),
#  ('lamps', 'JJ'),
#  ('skates', 'NNS'),
#  ('uhhh…', 'JJ'),
#  ('thinking', 'VBG'),
#  ('pajmena', 'JJ'),
#  ('miss', 'NN'),
#  ('is—i', 'NN'),
#  ('hungry', 'JJ'),
#  ('air', 'NN'),
#  ('guess', 'NN'),
#  ('.', '.'),
#  ('laughter', 'NN'),
#  ('hardy', 'JJ'),
#  ('mrs.', 'NN'),
#  ('scared', 'VBD'),
#  ('school', 'NN'),
#  ('embarassed', 'VBD'),
#  ('josh-u-a', 'NN'),
#  ('yeahh', 'NNS'),
#  ('magazine', 'NN'),
#  ('uhh…', 'JJ'),
#  ('coordinator', 'NN'),
#  ('weirdo', 'VBD'),
#  ('leads', 'VBZ'),
#  ('rub-rub-rub', 'JJ'),
#  ('know—', 'NNS'),
#  ('ve-we', 'JJ'),
#  ('elizabeth', 'NNS'),
#  ('can—you', 'VBP'),
#  ('thank', 'JJ'),
#  ('offensive', 'JJ'),
#  ('continue', 'NN'),
#  ('sad', 'JJ'),
#  ('floor', 'NN'),
#  ('flea', 'NN'),
#  ("you're-you", 'JJ'),
#  ('lent', 'NN'),
#  ('wall', 'NN'),
#  ('wel-wel-well', 'NN'),
#  ('belly', 'RB'),
#  ('ohhhhhhhh', 'JJ'),
#  ('outside…', 'NN'),
#  ('ahh…', 'NN'),
#  ('orient', 'NN'),
#  ('pooped', 'VBD'),
#  ('roommate', 'VB'),
#  ('discomfort', 'JJ'),
#  ('look-look', 'NN'),
#  ('twins', 'NNS'),
#  ('huh—wait', 'VBP'),
#  ('remote', 'JJ'),
#  ('fonzie', 'JJ'),
#  ('diversion', 'NN'),
#  ('half-hour', 'JJ'),
#  ('lamauge', 'JJ'),
#  ('bunnies', 'NNS'),
#  ('wh-', 'JJ'),
#  ('we…we', 'NN'),
#  ('waiting', 'VBG'),
#  ('twist', 'NN'),
#  ('3000', 'CD'),
#  ('junior', 'JJ'),
#  ('n-it', 'JJ'),
#  ('monday', 'NN'),
#  ('advance', 'NN'),
#  ('sorry', 'JJ'),
#  ('sisters', 'NNS'),
#  ('surprises', 'NNS'),
#  ('hats', 'NNS'),
#  ('le', 'VBP'),
#  ('exam', 'JJ'),
#  ('snowing', 'VBG'),
#  ('form', 'NN'),
#  ('el', 'NN'),
#  ('help', 'NN'),
#  ('explain', 'VB'),
#  ('misunderstanding', 'VBG'),
#  ('pitting', 'VBG'),
#  ('deals', 'NNS'),
#  ('joanne', 'VBP'),
#  ('him-', 'JJ'),
#  ('right', 'JJ'),
#  ('anastassakis/papasifakis', 'NN'),
#  ('cramp', 'NN'),
#  ('poster', 'NN'),
#  ('use', 'NN'),
#  ('aaron', 'JJ'),
#  ('pace', 'NN'),
#  ('i—we', 'NN'),
#  ('plan', 'NN'),
#  ('handy', 'JJ'),
#  ('shirt', 'JJ'),
#  ('free', 'JJ'),
#  ('remembered', 'VBD'),
#  ('picks', 'NNS'),
#  ('puzzle', 'VBP'),
#  ('ughh', 'JJ'),
#  ('blue', 'JJ'),
#  ('biblical', 'JJ'),
#  ('spread', 'NN'),
#  ('joins', 'VBZ'),
#  ('item', 'JJ'),
#  ('move', 'NN'),
#  ('montauk', 'NN'),
#  ('kitten', 'VBD'),
#  ('my—why', 'JJ'),
#  ('special', 'JJ'),
#  ('naming', 'JJ'),
#  ('scene', 'NN'),
#  ('pearls', 'NNS'),
#  ('fledermaus', 'VBP'),
#  ('cyborg', 'NNS'),
#  ('proposed', 'VBN'),
#  ('takin', 'JJ'),
#  ('look—no', 'NN'),
#  ('cliff', 'NN'),
#  ('bloomingdale', 'NN'),
#  ('areas', 'NNS'),
#  ('yankees', 'VBP'),
#  ('madeleines', 'NNS'),
#  ('dealer', 'NN'),
#  ('checkbook', 'NN'),
#  ('vows', 'VBZ'),
#  ('disagree', 'VBP'),
#  ('stay', 'NN'),
#  ('ran', 'VBD'),
#  ('alan', 'JJ'),
#  ('cabbage', 'NN'),
#  ('yeti—i', 'NN'),
#  ('greens', 'NNS'),
#  ('saran', 'VBD'),
#  ('cheeky', 'JJ'),
#  ('—', 'NNP'),
#  ('realises', 'NNS'),
#  ('glare', 'VBP'),
#  ('hm-m.', 'JJ'),
#  ('usher', 'NN'),
#  ('show', 'NN'),
#  ('stare', 'JJ'),
#  ('reps', 'VBZ'),
#  ("'inspiration", 'NN'),
#  ('wheeled', 'VBD'),
#  ('pancho', 'JJ'),
#  ('humoring', 'NN'),
#  ('afterwards', 'NNS'),
#  ('draddle', 'JJ'),
#  ('know—oh', 'VBP'),
#  ('none', 'NN'),
#  ('sock', 'NN'),
#  ('grappa', 'NN'),
#  ('rip', 'NN'),
#  ('forcing', 'VBG'),
#  ('bracelet', 'NN'),
#  ('note', 'NN'),
#  ('bored', 'VBD'),
#  ('curtain', 'NN'),
#  ('sympathize', 'NN'),
#  ('sneak', 'NN'),
#  ('grabbing', 'VBG'),
#  ('macadamia', 'NN'),
#  ('museum', 'NN'),
#  ('cleaning', 'VBG'),
#  ('stella', 'JJ'),
#  ('standard', 'NN'),
#  ('ross—really', 'RB'),
#  ('drawing', 'VBG'),
#  ('buddy', 'NN'),
#  ('resumes', 'NNS'),
#  ('instantly', 'RB'),
#  ('offers', 'VBZ'),
#  ('wrong', 'JJ'),
#  ('ohh—do', 'RB'),
#  ('98.50', 'CD'),
#  ('monster', 'NN'),
#  ('star', 'NN'),
#  ('foundation', 'NN'),
#  ('right…there', 'FW'),
#  ('work', 'NN'),
#  ('what/', 'JJ'),
#  ('way', 'NN'),
#  ('jokin', 'NN'),
#  ('taxing', 'VBG'),
#  ('mazel', 'JJ'),
#  ('asleep', 'JJ'),
#  ('carol…lesbian', 'JJ'),
#  ('mon', 'NN'),
#  ('no-no-no…', 'JJ'),
#  ('spring', 'NN'),
#  ('margaritas', 'NNS'),
#  ('helpful', 'JJ'),
#  ('earth', 'NN'),
#  ('drivers', 'NNS'),
#  ('italian', 'JJ'),
#  ('geez', 'NN'),
#  ('bags', 'NNS'),
#  ('just—wait', 'VBP'),
#  ('start', 'RB'),
#  ('drove', 'VB'),
#  ('aspirin', 'RB'),
#  ('uterus', 'JJ'),
#  ('right.i', 'NN'),
#  ('messing', 'VBG'),
#  ("i'll-i", 'JJ'),
#  ('pictionary', 'JJ'),
#  ("they'll-they", 'JJ'),
#  ('emily', 'RB'),
#  ('hardware', 'NN'),
#  ('cleared', 'JJ'),
#  ('water', 'NN'),
#  ('chasing', 'VBG'),
#  ('plastic', 'NN'),
#  ('kathy', 'NNS'),
#  ('glaring', 'VBG'),
#  ('mass-produced', 'JJ'),
#  ('slutty', 'NN'),
#  ('else', 'RB'),
#  ('spend', 'JJ'),
#  ('mormon', 'NN'),
#  ('handing', 'NN'),
#  ('joey…there', 'JJ'),
#  ('genitals', 'NNS'),
#  ('passionate', 'VBP'),
#  ('night..', 'JJ'),
#  ('seduce', 'NN'),
#  ('smoke', 'NN'),
#  ('hours', 'NNS'),
#  ('shin', 'VBP'),
#  ('adam', 'JJ'),
#  ('steal', 'NN'),
#  ('earn', 'VBP'),
#  ('graveyard', 'NN'),
#  ('momentary', 'NN'),
#  ('hi', 'NN'),
#  ("'love", 'IN'),
#  ('adjusting', 'VBG'),
#  ('took', 'VBD'),
#  ('court', 'NN'),
#  ('chocolates', 'NNS'),
#  ('auditorium', 'VBP'),
#  ('10th', 'CD'),
#  ('taurus', 'NN'),
#  ('crowd', 'VBD'),
#  ('t-shirt', 'JJ'),
#  ('24', 'CD'),
#  ('dies', 'NNS'),
#  ('basic', 'JJ'),
#  ('non-ugly', 'RB'),
#  ('ski', 'NN'),
#  ('also', 'RB'),
#  ('tanned', 'VBD'),
#  ('wo', 'MD'),
#  ('paris', 'VB'),
#  ('money', 'NN'),
#  ('ladies', 'NNS'),
#  ('prisoner', 'VBP'),
#  ('causing', 'VBG'),
#  ('long', 'JJ'),
#  ('twice', 'RB'),
#  ('dirty', 'JJ'),
#  ('exhibit', 'NN'),
#  ('allowed', 'VBN'),
#  ('fours', 'NNS'),
#  ('sent', 'VBD'),
#  ('defines', 'NNS'),
#  ('michelle', 'FW'),
#  ('crime', 'NN'),
#  ('odds', 'NNS'),
#  ('hey-whoa-whoa-whoa', 'JJ'),
#  ('making', 'VBG'),
#  ('seamstress', 'JJ'),
#  ('glue', 'JJ'),
#  ('agree', 'NN'),
#  ('you…are…not', 'NN'),
#  ("'cause", 'IN'),
#  ('checking', 'VBG'),
#  ('shhh', 'JJ'),
#  ('hope', 'NN'),
#  ('checks', 'NNS'),
#  ('blinds', 'VBZ'),
#  ('painful', 'JJ'),
#  ('—before', 'RB'),
#  ('hmmmm', 'JJ'),
#  ('supervision', 'NN'),
#  ('stewardess', 'NN'),
#  ('parking', 'VBG'),
#  ('bigger', 'JJR'),
#  ('shoop', 'NN'),
#  ('is—that', 'IN'),
#  ('cheech', 'NN'),
#  ("y'know", 'NN'),
#  ('bedrooms', 'VBZ'),
#  ('gay', 'JJ'),
#  ('turn', 'NN'),
#  ('ella', 'JJ'),
#  ('pom-poms', 'NNS'),
#  ('catch', 'NN'),
#  ('nipples', 'VBZ'),
#  ('sandy', 'JJ'),
#  ('at-at', 'JJ'),
#  ('week', 'NN'),
#  ('simultaneously', 'RB'),
#  ('drinks', 'VBZ'),
#  ('just…it', 'NN'),
#  ('club', 'NN'),
#  ('coffee', 'NN'),
#  ('sometimes', 'RB'),
#  ('ohh-ohh-oh', 'JJ'),
#  ('comes', 'VBZ'),
#  ('un-me', 'JJ'),
#  ('many', 'JJ'),
#  ('it…it', 'JJ'),
#  ('tillman', 'JJ'),
#  ('smart', 'JJ'),
#  ('bladder', 'NN'),
#  ('fifty', 'JJ'),
#  ('counts', 'VBZ'),
#  ('un-interested', 'JJ'),
#  ('yeah—but', 'NN'),
#  ('loses', 'VBZ'),
#  ('laugh', 'IN'),
#  ('looking', 'VBG'),
#  ('wrinkled', 'VBD'),
#  ('staring', 'VBG'),
#  ('cotton', 'NN'),
#  ('bunch', 'NN'),
#  ('danny', 'NN'),
#  ('tissues', 'NNS'),
#  ('incredibly', 'RB'),
#  ('y-yeah', 'VBP'),
#  ('27.', 'CD'),
#  ('expert', 'JJ'),
#  ('aware', 'JJ'),
#  ('i-i—would', 'JJ'),
#  ('jars', 'NNS'),
#  ('throws', 'VBZ'),
#  ("'cha", 'POS'),
#  ('officially', 'RB'),
#  ('progress', 'JJ'),
#  ('campbell', 'NN'),
#  ('antenna', 'NN'),
#  ('chases', 'NNS'),
#  ('distracted', 'VBD'),
#  ('danes', 'NNS'),
#  ('slippers', 'NNS'),
#  ('high', 'JJ'),
#  ('o-k', 'JJ'),
#  ('31.', 'CD'),
#  ('chain', 'NN'),
#  ('tah-daaah', 'JJ'),
#  ('surprise…', 'JJ'),
#  ('wo-women', 'NNS'),
#  ('taken', 'VBN'),
#  ('fast', 'RB'),
#  ('storing', 'JJ'),
#  ('bubbles', 'NNS'),
#  ('teeny-teeny', 'JJ'),
#  ('flicks', 'NNS'),
#  ('81', 'CD'),
#  ('s—we', 'NN'),
#  ('opens', 'VBZ'),
#  ('boxes', 'NNS'),
#  ('called', 'VBD'),
#  ('chase', 'JJ'),
#  ('just—we', 'NN'),
#  ('actor', 'NN'),
#  ('easy-pour', 'JJ'),
#  ('phoebe', 'NN'),
#  ('.ok.', 'NNP'),
#  ('artelle', 'VBZ'),
#  ('sec', 'JJ'),
#  ('trips', 'NNS'),
#  ('puberty', 'VBP'),
#  ('crabtree', 'JJ'),
#  ('ohio', 'NN'),
#  ('frame', 'NN'),
#  ('struggling', 'VBG'),
#  ('lemonade', 'NN'),
#  ('blushed', 'VBD'),
#  ('independence', 'NN'),
#  ('screams', 'NNS'),
#  ('hook', 'VBP'),
#  ('brat', 'JJ'),
#  ('earrings', 'NNS'),
#  ('sudden', 'JJ'),
#  ('violated', 'VBD'),
#  ('ex-husband', 'JJ'),
#  ('information', 'NN'),
#  ('damnit', 'NN'),
#  ('migrate', 'NN'),
#  ('anyway—umm', 'JJ'),
#  ('message', 'NN'),
#  ('hey', 'VBD'),
#  ('not-not', 'JJ'),
#  ('tire', 'NN'),
#  ('respond', 'NN'),
#  ('greasy', 'JJ'),
#  ('reflect', 'JJ'),
#  ('buys', 'NNS'),
#  ('merrill', 'RB'),
#  ('bothered', 'VBN'),
#  ('obscene', 'JJ'),
#  ('except', 'IN'),
#  ('ughhhh', 'JJ'),
#  ('eating', 'VBG'),
#  ('elbow', 'JJ'),
#  ('language', 'NN'),
#  ('maitre', 'NN'),
#  ('almost', 'RB'),
#  ('radisson', 'JJ'),
#  ('sick-o', 'JJ'),
#  ('cream', 'NN'),
#  ('turned', 'VBD'),
#  ('you…', 'RB'),
#  ('you—but', 'JJ'),
#  ('want', 'VBP'),
#  ('geller-green', 'JJ'),
#  ('christian', 'JJ'),
#  ('crush—and', 'NN'),
#  ('baby�s', 'VB'),
#  ('latour', 'NN'),
#  ('exited', 'VBN'),
#  ('hanger', 'NN'),
#  ('rubs', 'NN'),
#  ('delivery', 'NN'),
#  ('chatracus', 'NN'),
#  ("'ve", 'VBP'),
#  ('employee', 'NN'),
#  ('messed', 'VBN'),
#  ('aside', 'RB'),
#  ('squeeze', 'JJ'),
#  ('ohhhhhh', 'NN'),
#  ('jeez', 'NN'),
#  ('amateur', 'NN'),
#  ('behind', 'IN'),
#  ('mole', 'JJ'),
#  ('apologize', 'NNS'),
#  ('storming', 'VBG'),
#  ('kiss', 'JJ'),
#  ('marrying', 'VBG'),
#  ('hon-ey', 'JJ'),
#  ('dusting', 'VBG'),
#  ('sail', 'JJ'),
#  ('b-b-but', 'NN'),
#  ('up—i', 'JJ'),
#  ('hallway', 'RB'),
#  ('217.', 'CD'),
#  ('schemp', 'JJ'),
#  ('character', 'NN'),
#  ('luisa', 'VBP'),
#  ('master', 'NN'),
#  ('process', 'NN'),
#  ('page', 'NN'),
#  ('appology', 'NN'),
#  ('decaf', 'JJ'),
#  ('voice', 'NN'),
#  ('valentine', 'NN'),
#  ('king', 'VBG'),
#  ('joshua', 'NN'),
#  ('2', 'CD'),
#  ('ahhhhh', 'NN'),
#  ('sigma', 'NN'),
#  ('happ—i', 'NN'),
#  ('silly', 'RB'),
#  ('bed', 'VBD'),
#  ('around', 'IN'),
#  ('dead', 'JJ'),
#  ('lilies', 'NNS'),
#  ('antlers', 'NNS'),
#  ('oohh', 'VBP'),
#  ('dance', 'NN'),
#  ('him…', 'NN'),
#  ('promoted', 'VBD'),
#  ('aah', 'JJ'),
#  ('point', 'NN'),
#  ('metaphor', 'NN'),
#  ('jeopardising', 'VBG'),
#  ('welch', 'NN'),
#  ('confused', 'VBN'),
#  ('hesitates', 'VBZ'),
#  ('numbers', 'NNS'),
#  ('undressing', 'VBG'),
#  ('breathe', 'NN'),
#  ('screaming', 'VBG'),
#  ('lemon', 'JJ'),
#  ('morning', 'NN'),
#  ('aaahhhh', 'NN'),
#  ('shelley', 'NN'),
#  ('innuendoes', 'NNS'),
#  ('follow', 'VBP'),
#  ('definitely', 'RB'),
#  ('wooo', 'JJ'),
#  ('bleeding', 'VBG'),
#  ('ya', 'JJ'),
#  ('lance', 'NN'),
#  ('number', 'NN'),
#  ('what—yeah—what', 'WP'),
#  ('if-if', 'JJ'),
#  ('that—y', 'NN'),
#  ('beginning', 'VBG'),
#  ('beeped', 'VBD'),
#  ('beautiful…', 'JJ'),
#  ('unbelievable', 'JJ'),
#  ('sorry-', 'JJ'),
#  ('bastards', 'NNS'),
#  ('celebrates', 'VBZ'),
#  ('uncomfortable', 'JJ'),
#  ('shock', 'NN'),
#  ('good—i', 'NN'),
#  ('oooooooooh', 'JJ'),
#  ('stood', 'VBD'),
#  ('s-let', 'NN'),
#  ('jobs', 'NNS'),
#  ('teach', 'VBP'),
#  ('slut', 'JJ'),
#  ('pre-approved', 'JJ'),
#  ('cinamon', 'NN'),
#  ('europe', 'NN'),
#  ('sleeves', 'VBZ'),
#  ('restaurant', 'JJ'),
#  ('fame', 'NN'),
#  ('baked', 'VBD'),
#  ('hear—do', 'JJ'),
#  ('least', 'JJS'),
#  ('side', 'JJ'),
#  ('disregard', 'NN'),
#  ('juicy', 'NN'),
#  ('bum', 'NN'),
#  ('15', 'CD'),
#  ('umm…now', 'JJ'),
#  ('denis', 'NN'),
#  ('attracted', 'VBD'),
#  ('mork', 'NN'),
#  ('gets', 'VBZ'),
#  ('quickly', 'RB'),
#  ('killing', 'VBG'),
#  ('whiff', 'JJ'),
#  ('hi-e', 'JJ'),
#  ('i—i', 'NN'),
#  ('memories', 'NNS'),
#  ('pity-tone', 'CD'),
#  ('cents', 'NNS'),
#  ('wishful', 'JJ'),
#  ('hopes', 'NNS'),
#  ('waking', 'VBG'),
#  ('initiated', 'JJ'),
#  ('fashion-impaired', 'JJ'),
#  ('yeah-yeah', 'JJ'),
#  ('squishy', 'NN'),
#  ('healthy', 'JJ'),
#  ('nighttime', 'RB'),
#  ('chute', 'JJ'),
#  ('ass', 'NN'),
#  ('missed', 'VBD'),
#  ('like..', 'JJ'),
#  ('spirit', 'NN'),
#  ('sure', 'JJ'),
#  ('tuschy.', 'NN'),
#  ('calvin', 'NN'),
#  ('begin', 'VBP'),
#  ('3', 'CD'),
#  ('got—why', 'JJ'),
#  ('winner', 'NN'),
#  ('oh', 'JJ'),
#  ('resume', 'NN'),
#  ('flip', 'VBD'),
#  ('guy-in-van', 'JJ'),
#  ('sean', 'JJ'),
#  ('performance', 'NN'),
#  ('uh…well', 'NN'),
#  ('mug', 'RB'),
#  ('misjudged', 'VBD'),
#  ('too…', 'NN'),
#  ('neighbor', 'NN'),
#  ('ever', 'RB'),
#  ('lunchbox', 'VBZ'),
#  ('cross', 'NN'),
#  ('kill', 'NN'),
#  ('husband', 'NN'),
#  ('returns', 'NNS'),
#  ('score', 'VBP'),
#  ('gesture', 'NN'),
#  ('sixes', 'NNS'),
#  ('bitsy', 'VBD'),
#  ('34.', 'CD'),
#  ('drake', 'NN'),
#  ('blouse', 'NN'),
#  ('32c', 'CD'),
#  ('marry', 'NN'),
#  ('english', 'JJ'),
#  ('ohhh', 'RB'),
#  ('custard', 'JJ'),
#  ('wha', 'NN'),
#  ('crappy', 'JJ'),
#  ('silver', 'NN'),
#  ('sagittarius', 'NN'),
#  ('little…erotica', 'NN'),
#  ('mcdowell', 'NN'),
#  ('imitates', 'VBZ'),
#  ('sailing', 'VBG'),
#  ('offence', 'NN'),
#  ('craaaazy', 'NN'),
#  ('grandma', 'NN'),
#  ('sportswear', 'VBP'),
#  ('parachute', 'NN'),
#  ('back…', 'NN'),
#  ('hand', 'NN'),
#  ('suitcase', 'NN'),
#  ('mustard', 'NN'),
#  ('sex', 'NN'),
#  ('waitresses', 'VBZ'),
#  ('beg', 'JJ'),
#  ('la', 'NN'),
#  ('chucky', 'JJ'),
#  ('imitating', 'NN'),
#  ('lags', 'NNS'),
#  ('bath', 'NN'),
#  ('jumped', 'VBD'),
#  ('carefully', 'RB'),
#  ('buying', 'VBG'),
#  ('seen', 'VBN'),
#  ('noodles', 'NNS'),
#  ('sucks', 'NNS'),
#  ('yearbook', 'VBP'),
#  ('frilly', 'RB'),
#  ('digest', 'JJ'),
#  ('café', 'NN'),
#  ('relationship', 'NN'),
#  ('sconce', 'NN'),
#  ('wood', 'NN'),
#  ('gas', 'NN'),
#  ('starring', 'VBG'),
#  ('scratched', 'VBN'),
#  ('rivera', 'NN'),
#  ('tips', 'NNS'),
#  ('meee', 'RBR'),
#  ('possible', 'JJ'),
#  ('barry..', 'NN'),
#  ('landed', 'VBD'),
#  ('fire', 'NN'),
#  ('understanding', 'NN'),
#  ('neighborhood', 'JJ'),
#  ('pants', 'NNS'),
#  ('i-i—things', 'JJ'),
#  ('defends', 'NNS'),
#  ('capuchian', 'JJ'),
#  ('composure', 'NN'),
#  ('knock', 'NN'),
#  ('pam', 'NN'),
#  ('answers', 'NNS'),
#  ('m—here', 'RB'),
#  ('jessica', 'VBP'),
#  ('crush', 'NN'),
#  ('dorothy', 'NN'),
#  ('wow', 'NN'),
#  ('ambercrombie', 'NN'),
#  ('-teen', 'JJ'),
#  ('receptionist', 'JJ'),
#  ('uh-hmm', 'JJ'),
#  ('kidding—seriously', 'RB'),
#  ('later', 'RB'),
#  ('relived', 'VBN'),
#  ('hate', 'NN'),
#  ('antsy', 'NN'),
#  ('psyched', 'VBD'),
#  ('settings', 'NNS'),
#  ('sends', 'VBZ'),
#  ('hangover', 'JJ'),
#  ('wh-what', 'JJ'),
#  ('navy', 'JJ'),
#  ('sighs', 'NNS'),
#  ('girlish', 'JJ'),
#  ('hat..', 'NN'),
#  ('delicates', 'NNS'),
#  ('narrow', 'JJ'),
#  ('so..', 'JJ'),
#  ('s—she', 'NN'),
#  ('panicked', 'VBD'),
#  ('energy', 'NN'),
#  ('pass', 'NN'),
#  ('attention', 'NN'),
#  ('brighter', 'NN'),
#  ('matey', 'NN'),
#  ('shoppin', 'NN'),
#  ('time…she', 'NN'),
#  ('frozen', 'VBD'),
#  ('know…kissed', 'VBN'),
#  ('realize', 'NN'),
#  ('incredible', 'JJ'),
#  ('horribly', 'RB'),
#  ('signing', 'VBG'),
#  ('read—yes', 'NNS'),
#  ('support', 'NN'),
#  ('dreskin', 'VBP'),
#  ('soon', 'RB'),
#  ('uh…', 'JJ'),
#  ('liebawitz', 'NN'),
#  ('rrrooossss', 'NN'),
#  ('faking', 'VBG'),
#  ('refers', 'NNS'),
#  ('loner', 'RBR'),
#  ('extravagant', 'JJ'),
#  ('musings', 'NNS'),
#  ('raises', 'VBZ'),
#  ('sticking', 'VBG'),
#  ('matthew', 'NNS'),
#  ('breath', 'NN'),
#  ('sleeve', 'VBP'),
#  ('bridal', 'NN'),
#  ('excited', 'VBN'),
#  ('disbelief', 'JJ'),
#  ('caterers', 'NNS'),
#  ('they-they', 'JJ'),
#  ('stun', 'JJ'),
#  ('glamour', 'NN'),
#  ('48', 'CD'),
#  ('doooo', 'NN'),
#  ('couch', 'JJ'),
#  ('ugh…', 'JJ'),
#  ('that…', 'NN'),
#  ('storm', 'NN'),
#  ('held', 'VBD'),
#  ("i'm-i", 'JJ'),
#  ('you…oh', 'NN'),
#  ('pokes', 'NNS'),
#  ('floated', 'VBD'),
#  ('booze', 'JJ'),
#  ('rossy', 'JJ'),
#  ('chinese', 'JJ'),
#  ('robbing', 'VBG'),
#  ('packing', 'VBG'),
#  ('late', 'JJ'),
#  ('magic', 'NN'),
#  ('bristles', 'NNS'),
#  ('the…that', 'WDT'),
#  ('yeah—ooh', 'VBP'),
#  ('mean—i', 'JJ'),
#  ('november', 'NNP'),
#  ('voluntarily', 'RB'),
#  ('know', 'VBP'),
#  ('balloons', 'NNS'),
#  ('lasted', 'VBD'),
#  ('folder', 'RBR'),
#  ('trying', 'VBG'),
#  ('embarrassed', 'JJ'),
#  ('oh-oh-oh', 'JJ'),
#  ('just…made', 'NN'),
#  ('correspondence', 'NN'),
#  ('box', 'NN'),
#  ('kick-', 'JJ'),
#  ('mine', 'NN'),
#  ('phoebes', 'NN'),
#  ('manages', 'VBZ'),
#  ('sob', 'JJ'),
#  ('ii', 'JJ'),
#  ('answer', 'NN'),
#  ('true', 'JJ'),
#  ('squat', 'NN'),
#  ('marijuana', 'NN'),
#  ('spot', 'NN'),
#  ('however', 'RB'),
#  ('remotely', 'RB'),
#  ('awareness', 'JJ'),
#  ('territory', 'NN'),
#  ('muffin', 'NN'),
#  ('heads', 'NNS'),
#  ('think', 'VBP'),
#  ('pocket', 'NN'),
#  ('said', 'VBD'),
#  ('anytime', 'RB'),
#  ('baddest', 'JJ'),
#  ('pea', 'NN'),
#  ('bid', 'NN'),
#  ('colder', 'NN'),
#  ('kennedy', 'VBD'),
#  ('spit-on-your-neck', 'JJ'),
#  ('meeting', 'NN'),
#  ('hung', 'NN'),
#  ('oh..go..oh..and', 'VBP'),
#  ("bitchin'", 'NN'),
#  ('hire', 'NN'),
#  ('steele', 'NN'),
#  ('quick', 'JJ'),
#  ('effective', 'JJ'),
#  ('let', 'NN'),
#  ('losers', 'NNS'),
#  ('grandmother', 'VBP'),
#  ('inviting', 'VBG'),
#  ('and…you', 'RP'),
#  ('umbrella', 'JJ'),
#  ('trading', 'NN'),
#  ('upon', 'IN'),
#  ('cranking', 'VBG'),
#  ('no…', 'JJ'),
#  ('what�s', 'JJ'),
#  ('phoe-be', 'JJ'),
#  ('vuitton', 'NN'),
#  ('them…', 'NN'),
#  ('wet', 'JJ'),
#  ('wingman', 'JJ'),
#  ('issue', 'NN'),
#  ('headrest', 'JJS'),
#  ('est�', 'JJ'),
#  ('seasons', 'NNS'),
#  ('briefcase', 'VBP'),
#  ('tag', 'NN'),
#  ('reluctantly', 'RB'),
#  ('pfieffer', 'VBP'),
#  ('oh-ho', 'JJ'),
#  ('passes', 'NNS'),
#  ('london', 'VBP'),
#  ('clearly', 'RB'),
#  ('ahhhh…', 'RB'),
#  ('enriched', 'JJ'),
#  ('spots', 'NNS'),
#  ('wires', 'VBZ'),
#  ('honks', 'NNS'),
#  ('bottom', 'JJ'),
#  ('interrupt', 'JJ'),
#  ('sting', 'VBG'),
#  ('038', 'CD'),
#  ('clear', 'JJ'),
#  ('ink', 'NN'),
#  ('nato', 'JJ'),
#  ('uncle', 'NN'),
#  ('cuter', 'NN'),
#  ('pursuing', 'VBG'),
#  ('kudos', 'NNS'),
#  ('chi', 'VBN'),
#  ('pact', 'NN'),
#  ('fourth', 'JJ'),
#  ('chances', 'NNS'),
#  ('sight', 'VBD'),
#  ('frat', 'RB'),
#  ('sobbing', 'VBG'),
#  ('lure', 'NN'),
#  ('circles', 'NNS'),
#  ('revealing', 'VBG'),
#  ('carat', 'NN'),
#  ('prefers', 'NNS'),
#  ('breathing', 'VBG'),
#  ('office-door', 'JJ'),
#  ('daughter', 'NN'),
#  ('consummated', 'VBD'),
#  ('made', 'VBN'),
#  ('jewelry', 'NN'),
#  ('lobster…', 'NN'),
#  ('ears', 'NNS'),
#  ('relative', 'JJ'),
#  ('deltas', 'NNS'),
#  ('dejectedly', 'RB'),
#  ('gynecologist', 'VBP'),
#  ('leathery', 'NN'),
#  ('disgusted', 'VBD'),
#  ('26th', 'CD'),
#  ('jill', 'NN'),
#  ('perk', 'NN'),
#  ('(', '('),
#  ('explained', 'JJ'),
#  ('slams', 'NNS'),
#  ("i'm-", 'JJ'),
#  ('compromise', 'NN'),
#  ('farting', 'VBG'),
#  ('casserole', 'JJ'),
#  ('guys…', 'NN'),
#  ('sputtery', 'NN'),
#  ('gasp', 'NN'),
#  ('clasp', 'JJ'),
#  ('central', 'JJ'),
#  ('mimics', 'NNS'),
#  ('publicity', 'NN'),
#  ('chippy', 'JJ'),
#  ('triumph', 'NN'),
#  ('rack', 'NN'),
#  ('this…', 'NN'),
#  ('porsching', 'VBG'),
#  ('jabba', 'JJ'),
#  ('sets', 'NNS'),
#  ('survived', 'VBD'),
#  ('son', 'NN'),
#  ('married—i', 'NN'),
#  ('climbs', 'JJ'),
#  ('waffles', 'VBZ'),
#  ('actually—i-i', 'JJ'),
#  ...]

# %%
"""Appending words into character's(RACHEL)strings """
s_rachel=""
for w in stem_freq_words_rach:
   s_rachel=s_rachel+' '+w

s_rachel
# Out:
# " playpen try table buries research bye-bye lickers espn batch spanish forget you�re t…leave taught faith customer horoscope veil rome whispering irritating part insane nancy crummy virgin hiding nooo sided planetarium… nooooooooo due noone boat coloured two-piece one..we spell 'till really probably quite post wallis somewhat clause done pause cigs minute blonde nod haze wife hey-hey-hey response gavin c'mon newspaper pierced eventually character overheard rich thing peeping halloween small on—joey anticipation joey— umm…oh…who 'good blow knew older helmut pony flap great-great practising time cosmopolitan related brosnan like… kids… maybe induce circley haphazard traumatic mass dock stain baby mattered girlfriend undo kicked pouring pile funeral boxer becker perspective badminton movement pizza disembarks bing sooo appears lamp skate uhhh… thinking pajmena miss is—i hungry guess laughter hardy mrs. scared school embarassed josh-u-a yeahh magazine uhh… coordinator weirdo lead rub-rub-rub know— ve-we elizabeth can—you thank offensive continue floor flea you're-you lent wall wel-wel-well belly ohhhhhhhh outside… ahh… orient pooped roommate discomfort look-look twin huh—wait remote fonzie diversion half-hour lamauge bunny we…we waiting twist 3000 junior n-it monday advance sorry sister surprise hat exam snowing form help explain misunderstanding pitting deal joanne him- right anastassakis/papasifakis cramp poster aaron pace i—we plan handy shirt free remembered pick puzzle ughh blue biblical spread join item move montauk kitten my—why special naming scene pearl fledermaus cyborg proposed takin look—no cliff bloomingdale area yankee madeleines dealer checkbook vow disagree stay alan cabbage yeti—i green saran cheeky realises glare hm-m. usher show stare rep 'inspiration wheeled pancho humoring afterwards draddle know—oh none sock grappa forcing bracelet note bored curtain sympathize sneak grabbing macadamia museum cleaning stella standard ross—really drawing buddy resume instantly offer wrong ohh—do 98.50 monster star foundation right…there work what/ jokin taxing mazel asleep carol…lesbian no-no-no… spring margarita helpful earth driver italian geez bag just—wait start drove aspirin uterus right.i messing i'll-i pictionary they'll-they emily hardware cleared water chasing plastic kathy glaring mass-produced slutty else spend mormon handing joey…there genitals passionate night.. seduce smoke hour shin adam steal earn graveyard momentary 'love adjusting took court chocolate auditorium 10th taurus crowd t-shirt dy basic non-ugly also tanned paris money lady prisoner causing long twice dirty exhibit allowed four sent defines michelle crime odds hey-whoa-whoa-whoa making seamstress glue agree you…are…not 'cause checking shhh hope check blind painful —before hmmmm supervision stewardess parking bigger shoop is—that cheech y'know bedroom turn ella pom-pom catch nipple sandy at-at week simultaneously drink just…it club coffee sometimes ohh-ohh-oh come un-me many it…it tillman smart bladder fifty count un-interested yeah—but loses laugh looking wrinkled staring cotton bunch danny tissue incredibly y-yeah expert aware i-i—would jar throw 'cha officially progress campbell antenna chase distracted dane slipper high chain tah-daaah surprise… wo-women taken fast storing bubble teeny-teeny flick s—we open box called chase just—we actor easy-pour phoebe .ok. artelle trip puberty crabtree ohio frame struggling lemonade blushed independence scream hook brat earring sudden violated ex-husband information damnit migrate anyway—umm message not-not tire respond greasy reflect buy merrill bothered obscene except ughhhh eating elbow language maitre almost radisson sick-o cream turned you… you—but want geller-green christian crush—and baby�s latour exited hanger rub delivery chatracus employee messed aside squeeze ohhhhhh jeez amateur behind mole apologize storming kiss marrying hon-ey dusting sail b-b-but up—i hallway 217. schemp character luisa master  ...

# %%
"""Appending words into character's(ROSS)strings """
s_ross=""
for w in stem_freq_words_ross:
   s_ross=s_ross+' '+w

s_ross
# Out:
# " playpen try table blonde research avoid bye-bye espn batch forget cheat you�re shell ornamental re…uh…they taught bridge rome whispering hovering graduate part insane restrung radioactive booth startling d-13 virgin disappointing nooo firm shoulda y'know-y'know noone not-i goal exist subcategorized 'till really bread probably crinkle quite post origin you're—hey argentinasaurus shaker winterberry done …subcategories pause film…that minute blonde nod wh-wh-wh-where wife hey-hey-hey valuable spoon decorated response scum wealer c'mon pierced eventually character stressed overheard i…uh rich scooch thing small curator valid cathedral meet in—no blow knew librarian older weird.. racquet appraise t-rex anniversary countdown match mwwwooooo-hah-hah sucked time entitled related lower bookstore account like… kids… maybe bowe but-but traumatic barracuda baby girlfriend kicked aid explosion kinda…y pile but…but we-we-we funeral ease… bit…hit perspective pizza bing appears skate thinking pajmena miss match grip hungry guess laughter mrs. scared school embarassed muffin blast magazine uhh… astaire leakey —twenty-eight ve-we elizabeth my-my-my uberveiss thank cutout transportation incredulous dustpan under-panty procedure height floor flea prize you're-you lent sexretary maria i-i-i… whatsoever wall just_ about…about belly roommate look-look ouchy twin remote fonzie corn have…sex-uh salted if…if honorary bunny bird�s we…we waiting skirt chunky junior neat monday sorry sister videotape ezel delicate we-we- shawn hypothetical stupidly exam form apartment—although post help explain agressive immature misunderstanding deal um…i right poster aaron caster plan strain alumnus shirt cork 'bout nobel threatened free family mount pick puzzle blue weirder spread uh…coconutty join mmm-unmm item whine move tanning special scene altogether proposed repel see…a software sake bloomingdale area good-bye something.. 'dumped madeleines vow disagree stay alan here—but saran lollypop realises glare show stare sublet centazoic gilbert murray none sock falter but…darwin the-how grill taping forcing note bored wait—hold sneak convinced grabbing head-butting brinkley weakly macadamia museum cleaning drawing wing brother-in-law m-maybe buddy resume offer instantly wrong polisher *enough* nurturing monster star foundation half-full work nectarine twisted sidecar printed breed christmassy eighteenth fireball asleep laverne instrament sheep spring margarita helpful earth complain italian bag math belt start aspirin uterus messing i…what emily water chasing ridden goalie plastic kathy glaring kinda….. slutty else spend seize …will interplanetary laugh/groan handing hidden use.. passionate browsing hour earful steal earn applying momentary artwork genuine cruising took court chocolate 10th crowd t-shirt late- loyal wink do-able ready nonono dy previous alike also tanned w-wait vendor paris smarter canidates money life… mmmm cous-cous lady prisoner whaa long twice applied dirty aired demonstrates shuffleboard exhibit allowed muhlbrat was…that needy sent same… michelle crime odds phenomenon making glue agree andrea generous academic 'cause checking shhh hope check sport model flower rain… painful parking ezels steamy bigger y'know enjoys turn ella j437-a sandy catch nipple typing do-i week lecturer simultaneously drink club .does coffee sometimes product come burlesque many fluoresces such-such smart tackle fifty count directly loses laugh looking hiking staring half-eaten newfound chan bunch this-this-this incredibly aware homo-erectus throw 'cha crab millners antenna divorcer chase distracted pen nasal high waddle humping chain villager taken fast wooden silvia lesbinims errrr open box called bathe chef balance temperature chase distraction fonzy actor barber phoebe chemistry odorless definitive 007. bedankt death-cab the—how think- ohio frame wood-burning struggling lemonade scream hook what—look —what sudden ex-husband lovingly damnit information is—you— new… draft  ...

# %%
"""Appending words into character's(PHOEB)strings """
s_phoebs=""
for w in stem_freq_words_phoebs:
   s_phoebs=s_phoebs+' '+w

s_phoebs
# Out:
# " human playpen try table know..near research bye-bye batch forget cheat you�re ello taught bridge faith horoscope veil whispering hovering turkey part insane radioactive solo startling corp hiding virgin nooo firm detailed shoplifting exist 'till really dealership bread probably quite post clause done pause minute blonde nod wife spoon decorated lurk pac-man c'mon newspaper knocker eventually deep-deep-deep overheard killer rich thing -football stripan halloween toys… small compare rehab ho-o-ot blow knew older study titweiller flap 'cos about…everything wedgie 9:15 passageway time unfold lower bookstore like… revolutionary maybe shave but-but cubed stain baby wisecracking girlfriend undo kicked grass mugging merchant funeral boxer ease… ground-up sell… perspective pizza bing sooo appears thinking applause miss match hungry guess laughter mrs. scared school boat—this deeper this..umm..emily marjorie blast magazine plate organic weirdo 401k ladle elizabeth thank sticky-sticky transportation height but—y exellent floor flea prize you're-you abby self whatsoever wall worked- thermos roommate geller-bing look-look twin fonzie remote corn half-hour north bunny wethering waiting junior 3000 neat monday sorry sister hat my—didn exam snowing form opium climbed help explain yuh-huh right together… strength poster i—we plan contain shirt nobel credited threatened he-hee free family remembered scene pick brake trimester blue wondrous spread join item evaporate/smoke move tremendously montauk special naming scene pharmaceutical cyborg proposed sake form… cliff capsule bloomingdale 'javu'..will dealer embrace louisiana stay alan morly realises glare aversion stare show pancho meadow draddle could— none sock indicating chandelier vibrate bracelet note bored expense sneak coward convinced rapist grabbing museum cleaning knock-offs drawing buddy resume offer wrong reginé roller-skating monster star touchy checker work twisted omaha cardboard mazel secretary fireball lend asleep priiiize helpful complain italian bag math pricing start drove ew-eww uterus emily water cellphone plastic kathy god. skedaddle else spend upper benefit handing hidden passionate smoke hour steal earn inconvenience applying gladiator took court jake crowd t-shirt ooh-ahh wink heart-shaped dy alike also on-on vendor paris money favorite that—it i'ts swore lady prisoner causing long twice dirty re-wired exhibit allowed needy sent michelle mikey crime odds making glue agree tiger generous 'cause checking shhh hope check model mmm…hmmmmm… painful hmmmm supervision bigger y'know turn yarn sandy catch at-at week simultaneously drink club coffee sometimes iceman come many innocent smart bladder fifty count directly loses nick feburary laugh looking detour staring cotton t-they bunch tissue this-this-this incredibly slum won�t aware throw ganja penetrate fails chase distracted slipper high s—uck humping chain taken fast bubble wooden beanstalk open box i-i…i called massage-yourself-at-home-workshop chase actor phoebe chemistry 9:00 jenkins frame struggling hook station earring sudden ex-husband violated information damnit widow message not-not tire make… detector specified merrill yes..is except stooge endeavour dull broth language slot almost nacho shoot cream turned you… salt want specie mouthful instruction christian vous potion latour delivery hanger blaster provide so…vanilla price messed aside squeeze punishment rdtor 7.50 bathed jeez comic mahogany behind offing ah-uh rattle and- concern apologize salami kiss marrying hideous mime sail hacky honesty hallway movement grip includes character master process page search decaf t�not voice partner valentine king fighting garlic bee silly tusk insider around dead dance promoted monica�s donald point confused jingle number punching performance reassure breathe screaming morning restarts frenaissance pairing one-eyed lay-up helmet-pelts caging straw follow definitely boxy wooo bleeding duck there's—no toulouse um-mmm lance numb ...

# %%
"""Appending words into character's(JOE)strings """
s_joe=""
for w in stem_freq_words_joe:
   s_joe=s_joe+' '+w

# %%
"""Appending words into character's(CHANDLER)strings """
s_chandler=""
for w in stem_freq_words_chandler:
   s_chandler=s_chandler+' '+w

# %%
"""Appending words into character's(MONICA)strings """
s_mon=""
for w in stem_freq_words_mon:
   s_mon=s_mon+' '+w

# %% [markdown]
# It's an open conversation. Everyone talks to everbody else.
# They all talk in a similar way -mingle well with each other

# %%
dicti={}
"""Establishing connection with Ibm watson using autentication key"""
authenticator = IAMAuthenticator('7iWlOedWeTpgREu12do8yDjjxHC3WiNrc593r4sAjrdC')
natural_language_understanding = NaturalLanguageUnderstandingV1(
   authenticator=authenticator,
    version='2019-07-25')
natural_language_understanding.set_service_url('https://gateway.watsonplatform.net/natural-language-understanding/api')                           

#natural_language_understanding = NaturalLanguageUnderstandingV1(
#        iam_apikey='7iWlOedWeTpgREu12do8yDjjxHC3WiNrc593r4sAjrdC',
#        version='2019-07-25',
#        url='https://gateway.watsonplatform.net/natural-language-understanding/api'
#    )
##rachel

response = natural_language_understanding.analyze(
    text=s_rachel,
    features=Features(emotion=EmotionOptions())).get_result()
print("Rachel")
print("======================================")
dicti["Rachel"]=response["emotion"]["document"]["emotion"]

print(json.dumps(response["emotion"]["document"]["emotion"], indent=2))

#print(json.dumps(response, indent=2))

##ross
response = natural_language_understanding.analyze(
    text=s_ross,
    features=Features(emotion=EmotionOptions())).get_result()
print("Ross")
print("======================================")
dicti["Ross"]=response["emotion"]["document"]["emotion"]

print(json.dumps(response["emotion"]["document"]["emotion"], indent=2))

##monica
response = natural_language_understanding.analyze(
    text=s_mon,
    features=Features(emotion=EmotionOptions())).get_result()
print("Monica")
dicti["Monica"]=response["emotion"]["document"]["emotion"]

print("======================================")
print(json.dumps(response["emotion"]["document"]["emotion"], indent=2))

##phoebe
response = natural_language_understanding.analyze(
    text=s_phoebs,
    features=Features(emotion=EmotionOptions())).get_result()
print("Phoebe")
dicti["Phoebe"]=response["emotion"]["document"]["emotion"]

print("======================================")
print(json.dumps(response["emotion"]["document"]["emotion"], indent=2))

#chandler
response = natural_language_understanding.analyze(
    text=s_chandler,
    features=Features(emotion=EmotionOptions())).get_result()
print("Chandler")
print("======================================")
dicti["Chandler"]=response["emotion"]["document"]["emotion"]

print(json.dumps(response["emotion"]["document"]["emotion"], indent=2))

#joey
response = natural_language_understanding.analyze(
    text=s_joe,
    features=Features(emotion=EmotionOptions())).get_result()

print("Joey")
print("======================================")
dicti["Joey"]=response["emotion"]["document"]["emotion"]

print(json.dumps(response["emotion"]["document"]["emotion"], indent=2))
print(json.dumps(dicti, indent=2))
# Out:
# Rachel
# ======================================
# {
#   "sadness": 0.555311,
#   "joy": 0.480405,
#   "fear": 0.200402,
#   "disgust": 0.496291,
#   "anger": 0.477182
# }
# Ross
# ======================================
# {
#   "sadness": 0.570401,
#   "joy": 0.497011,
#   "fear": 0.180297,
#   "disgust": 0.179913,
#   "anger": 0.491127
# }
# Monica
# ======================================
# {
#   "sadness": 0.585658,
#   "joy": 0.568719,
#   "fear": 0.186227,
#   "disgust": 0.19985,
#   "anger": 0.239249
# }
# Phoebe
# ======================================
# {
#   "sadness": 0.615632,
#   "joy": 0.55482,
#   "fear": 0.181937,
#   "disgust": 0.162579,
#   "anger": 0.480413
# }
# Chandler
# ======================================
# {
#   "sadness": 0.59252,
#   "joy": 0.580444,
#   "fear": 0.565659,
#   "disgust": 0.162596,
#   "anger": 0.192459
# }
# Joey
# ======================================
# {
#   "sadness": 0.58179,
#   "joy": 0.540839,
#   "fear": 0.159252,
#   "disgust": 0.462552,
#   "anger": 0.200329
# }
# {
#   "Rachel": {
#     "sadness": 0.555311,
#     "joy": 0.480405,
#     "fear": 0.200402,
#     "disgust": 0.496291,
#     "anger": 0.477182
#   },
#   "Ross": {
#     "sadness": 0.570401,
#     "joy": 0.497011,
#     "fear": 0.180297,
#     "disgust": 0.179913,
#     "anger": 0.491127
#   },
#   "Monica": {
#     "sadness": 0.585658,
#     "joy": 0.568719,
#     "fear": 0.186227,
#     "disgust": 0.19985,
#     "anger": 0.239249
#   },
#   "Phoebe": {
#     "sadness": 0.615632,
#     "joy": 0.55482,
#     "fear": 0.181937,
#     "disgust": 0.162579,
#     "anger": 0.480413
#   },
#   "Chandler": {
#     "sadness": 0.59252,
#     "joy": 0.580444,
#     "fear": 0.565659,
#     "disgust": 0.162596,
#     "anger": 0.192459
#   },
#   "Joey": {
#     "sadness": 0.58179,
#     "joy": 0.540839,
#     "fear": 0.159252,
#     "disgust": 0.462552,
#     "anger": 0.200329
#   }
# }

# %%
df = pd.DataFrame(dicti)

df.transpose().plot(kind='bar')

# %%
df.head()
# Out:
#            Rachel      Ross    Monica    Phoebe  Chandler      Joey
# anger    0.477182  0.491127  0.239249  0.480413  0.192459  0.200329
# disgust  0.496291  0.179913  0.199850  0.162579  0.162596  0.462552
# fear     0.200402  0.180297  0.186227  0.181937  0.565659  0.159252
# joy      0.480405  0.497011  0.568719  0.554820  0.580444  0.540839
# sadness  0.555311  0.570401  0.585658  0.615632  0.592520  0.581790

# %%
happy_quotient_Rach=df.Rachel.joy/df['Rachel'].sum()
happy_quotient_Ross=df.Ross.joy/df['Ross'].sum()
happy_quotient_Joey=df.Joey.joy/df['Joey'].sum()
happy_quotient_Monica=df.Monica.joy/df['Monica'].sum()
happy_quotient_Phoebe=df.Phoebe.joy/df['Phoebe'].sum()
happy_quotient_Chandler=df.Chandler.joy/df['Chandler'].sum()

# %%
sadness_quotient_Rach=df.Rachel.sadness/df['Rachel'].sum()
sadness_quotient_Ross=df.Ross.sadness/df['Ross'].sum()
sadness_quotient_Joey=df.Joey.sadness/df['Joey'].sum()
sadness_quotient_Monica=df.Monica.sadness/df['Monica'].sum()
sadness_quotient_Phoebe=df.Phoebe.sadness/df['Phoebe'].sum()
sadness_quotient_Chandler=df.Chandler.sadness/df['Chandler'].sum()

# %%
Disgusting_quotient_Rach=df.Rachel.disgust/df['Rachel'].sum()
Disgusting_quotient_Ross=df.Ross.disgust/df['Ross'].sum()
Disgusting_quotient_Joey=df.Joey.disgust/df['Joey'].sum()
Disgusting_quotient_Monica=df.Monica.disgust/df['Monica'].sum()
Disgusting_quotient_Phoebe=df.Phoebe.disgust/df['Phoebe'].sum()
Disgusting_quotient_Chandler=df.Chandler.disgust/df['Chandler'].sum()

# %%
Fear_quotient_Rach=df.Rachel.fear/df['Rachel'].sum()
Fear_quotient_Ross=df.Ross.fear/df['Ross'].sum()
Fear_quotient_Joey=df.Joey.fear/df['Joey'].sum()
Fear_quotient_Monica=df.Monica.fear/df['Monica'].sum()
Fear_quotient_Phoebe=df.Phoebe.fear/df['Phoebe'].sum()
Fear_quotient_Chandler=df.Chandler.fear/df['Chandler'].sum()

# %%
Anger_quotient_Rach=df.Rachel.anger/df['Rachel'].sum()
Anger_quotient_Ross=df.Ross.anger/df['Ross'].sum()
Anger_quotient_Joey=df.Joey.anger/df['Joey'].sum()
Anger_quotient_Monica=df.Monica.anger/df['Monica'].sum()
Anger_quotient_Phoebe=df.Phoebe.anger/df['Phoebe'].sum()
Anger_quotient_Chandler=df.Chandler.anger/df['Chandler'].sum()

# %%
x_happy = ['Rachel','Ross','Joey','Monica','Phoebe','Chandler']
y_happy = [happy_quotient_Rach,happy_quotient_Ross,happy_quotient_Joey,happy_quotient_Monica,happy_quotient_Phoebe,happy_quotient_Chandler]
colors = ['r','g','b','y','cyan','m']
plt.scatter(x_happy,y_happy,s=120, c=colors)
plt.title('Happiness Quotient for the Characters')
plt.show()

# %%
x_sad = ['Rachel','Ross','Joey','Monica','Phoebe','Chandler']
y_sad = [sadness_quotient_Rach,sadness_quotient_Ross,sadness_quotient_Joey,sadness_quotient_Monica,sadness_quotient_Phoebe,sadness_quotient_Chandler]
colors = ['r','g','b','y','cyan','m']
plt.scatter(x_sad,y_sad,s=120, c=colors)
plt.title('Sadness Quotient for the Characters')
plt.show()

# %%
x_fear = ['Rachel','Ross','Joey','Monica','Phoebe','Chandler']
y_fear = [Fear_quotient_Rach,Fear_quotient_Ross,Fear_quotient_Joey,Fear_quotient_Monica,Fear_quotient_Phoebe,Fear_quotient_Chandler]
colors = ['r','g','b','y','cyan','m']
plt.scatter(x_fear,y_fear,s=120, c=colors)
plt.title('Fear Quotient for the Characters')
plt.show()

# %%
x_disgust = ['Rachel','Ross','Joey','Monica','Phoebe','Chandler']
y_disgust = [Disgusting_quotient_Rach,Disgusting_quotient_Ross,Disgusting_quotient_Joey,Disgusting_quotient_Monica,Disgusting_quotient_Phoebe,Disgusting_quotient_Chandler]
colors = ['r','g','b','y','cyan','m']
plt.scatter(x_disgust,y_disgust,s=120, c=colors)
plt.title('Disgusting Quotient for the Characters')
plt.show()

# %%
x_anger = ['Rachel','Ross','Joey','Monica','Phoebe','Chandler']
y_anger = [Anger_quotient_Rach,Anger_quotient_Ross,Anger_quotient_Joey,Anger_quotient_Monica,Anger_quotient_Phoebe,Anger_quotient_Chandler]
colors = ['r','g','b','y','cyan','m']
plt.scatter(x_anger,y_anger,s=120, c=colors)
plt.title('Anger Quotient for the Characters')
plt.show()

# %%
plt.subplot(3, 2, 1)
plt.scatter(x_happy,y_happy,s=120, c=colors)
plt.title('Happiness Quotient for the Characters')

plt.subplot(3, 2, 2)
plt.scatter(x_anger,y_anger,s=120, c=colors)
plt.title('Anger Quotient for the Characters')

plt.subplot(3, 2, 3)
plt.scatter(x_sad,y_sad,s=120, c=colors)
plt.title('Sadness Quotient for the Characters')

plt.subplot(3, 2, 4)
plt.scatter(x_fear,y_fear,s=120, c=colors)
plt.title('Fear Quotient for the Characters')

plt.subplot(3, 2, 5)
plt.scatter(x_disgust,y_disgust,s=120, c=colors)
plt.title('Disgusting Quotient for the Characters')


plt.show()

# %%
df.plot(kind='bar')
plt.show()

# %%
df.transpose().plot(kind='bar')
plt.show()

# %%
df1=df.transpose()
df1
# Out:
#              anger   disgust      fear       joy   sadness
# Rachel    0.477182  0.496291  0.200402  0.480405  0.555311
# Ross      0.491127  0.179913  0.180297  0.497011  0.570401
# Monica    0.239249  0.199850  0.186227  0.568719  0.585658
# Phoebe    0.480413  0.162579  0.181937  0.554820  0.615632
# Chandler  0.192459  0.162596  0.565659  0.580444  0.592520
# Joey      0.200329  0.462552  0.159252  0.540839  0.581790

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Anger', 'Disgust', 'Fear', 'Joy', 'Sadness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df.Rachel, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Rachel')
plt.show()

# %% [markdown]
# <br />
# <center>
#     <img src="picsforfriends/rach.jpg" width=400 height=100 />
# </center>

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Anger', 'Disgust', 'Fear', 'Joy', 'Sadness']
explode = (0.2, 0.3, 0, 0.2, 0.1)
plt.pie(df.Ross, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Ross')
plt.show()

# %% [markdown]
# <br />
# <center>
#     <img src="picsforfriends/ross.png" width=400 height=100 />
# </center>

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Anger', 'Disgust', 'Fear', 'Joy', 'Sadness']
explode = (0.2, 0.3, 0, 0.2, 0.1)
plt.pie(df.Monica, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Monica')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Anger', 'Disgust', 'Fear', 'Joy', 'Sadness']
explode = (0.2, 0.3, 0, 0.2, 0.1)
plt.pie(df.Chandler, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Chandler')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Anger', 'Disgust', 'Fear', 'Joy', 'Sadness']
explode = (0.2, 0.3, 0, 0.2, 0.1)
plt.pie(df.Joey, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Joey')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Anger', 'Disgust', 'Fear', 'Joy', 'Sadness']
explode = (0.2, 0.3, 0, 0.2, 0.1)
plt.pie(df.Phoebe, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Phoebe')
plt.show()

# %%
 plotwordcloud(s_chandler)

# %%
 plotwordcloud(s_rachel)

# %%
 plotwordcloud(s_ross)

# %%
 plotwordcloud(s_joe)

# %%
 plotwordcloud(s_phoebs)

# %%
plotwordcloud(s_mon)
